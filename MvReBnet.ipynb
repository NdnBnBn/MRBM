# %%
import biolqm
import ginsim
import functools
import itertools
import logging
import operator
import random
from typing import Optional

import networkx

import pyboolnet.state_space
from pyboolnet import find_command
from pyboolnet import prime_implicants
from pyboolnet.digraphs import add_style_subgraphs, digraph2image
from pyboolnet.digraphs import find_ancestors, find_outdag
from pyboolnet.helpers import copy_json_data, save_json_data, open_json_data
from pyboolnet.helpers import dicts_are_consistent, merge_dicts
from pyboolnet.helpers import perc2str, divide_list_into_similar_length_lists
from pyboolnet.interaction_graphs import primes2igraph
from pyboolnet.model_checking import model_checking
from pyboolnet.prime_implicants import copy_primes, remove_all_variables_except
from pyboolnet.prime_implicants import list_input_combinations, find_inputs
from pyboolnet.state_space import size_state_space, subspace2str
from pyboolnet.state_transition_graphs import UPDATE_STRATEGIES
from pyboolnet.temporal_logic import subspace2proposition
from pyboolnet.commitment_diagrams import _project_attractors
from pyboolnet.commitment_diagrams import _cartesian_product_of_diagrams
from pyboolnet.commitment_diagrams import _lift_attractors
import pyboolnet

import numpy as np
import pandas as pd

from pyboolnet import attractors
from pyboolnet import basins_of_attraction
from pyboolnet import commitment_diagrams
from pyboolnet import file_exchange
from pyboolnet import phenotypes
from pyboolnet import state_space
from pyboolnet import state_transition_graphs
from pyboolnet import network_generators
from pyboolnet import model_checking
from pyboolnet import temporal_logic
from pyboolnet import boolean_logic




from itertools import combinations
from colomoto import minibn
from colomoto_jupyter import tabulate
import os.path
import mpbn
import json
import copy
# Out:
# This notebook has been executed using the docker image `colomoto/colomoto-docker` built on `2023-12-30`
# <script type="text/javascript" id="colomoto-setup-5643608" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
# function detect_import(cell, module) {
#     var code = cell.get_text();
#     code = code.replace(/\\\n/g, "");
#     var lines = code.split("\n");
#     var r_simple = new RegExp("^("+module+")$");
#     var r_alias = new RegExp("^"+module+"\\s+as\\s+(\\w+)$");
#     for (var i = 0; i < lines.length; ++i) {
#         if (/^import\s/.test(lines[i])) {
#             code = lines[i].substr(7);
#             var parts = code.split(",")
#             for (var j = 0; j < parts.length; ++j) {
#                 code = parts[j].trim();
#                 var m = code.match(r_simple);
#                 if (!m) {
#                     m = code.match(r_alias);
#                 }
#                 if (m) {
#                     return m[1];
#                 }
#             }
#         }
#     }
#     return module;
# }
#
# function colomoto_replace_call(cell, orig, dest, args, comment=false) {
#     var call_regexp = new RegExp("\\."+orig.replace(".","\\.")+"\\(");
#     var call_replacer = new RegExp("\\."+orig.replace(".","\\.")
#                     + "\\(\\s*([^\\)]*)?\\)");
#     var code = cell.get_text();
#     var lines = code.split("\n");
#     if (args) {
#         var strargs = ", "+args.join(", ");
#     } else {
#         var strargs = "";
#     }
#     for (var i = 0; i < lines.length; ++i) {
#         if (call_regexp.test(lines[i])) {
#             var code = ""
#             if (comment) {
#                 code += "#"+lines[i]+"\n";
#             }
#             code += lines[i].replace(call_replacer, "."+dest+"($1"+strargs+")")
#             lines[i] = code;
#         }
#     }
#     cell.set_text(code)
# }
#
# function colomoto_upload(Jupyter, ssid, input, py_callback_name, orig, dest) {
#
#     function callback(out_data) {
#         var cell_element = $("#"+ssid).parents('.cell');
#         var cell_idx = Jupyter.notebook.get_cell_elements().index(cell_element);
#         var cell = Jupyter.notebook.get_cell(cell_idx);
#
#         var filename = out_data.content.text;
#
#         var code = cell.get_text();
#         code = code.replace(new RegExp("\\b" + orig.replace('.', '\\.')
#                     + "\\(\\s*((\\w+)=[^\\)]*)?\\)"),
#                 dest+"(\""+filename+"\",$1)");
#         code = code.replace('",)', '")')
#         cell.set_text(code);
#
#         Jupyter.notebook.select(cell_idx);
#         Jupyter.notebook.execute_cell_and_select_below();
#     }
#
#     if (! (window.File && window.FileReader && window.FileList && window.Blob)) {
#         alert("Interactive file upload is not supported by your browser.");
#         return;
#     }
#
#     input.disabled = true;
#     input.style.cursor = "wait";
#     input.parentElement.style.cursor = "wait";
#
#     var f = input.files[0];
#     var reader = new FileReader();
#     reader.onload = (function(f) {
#         return function (e) {
#             var obj = {
#                 content: e.target.result,
#                 name: f.name
#             };
#
#             //var pycb = py_callback_name+"("+JSON.stringify(obj)+")"
#             // hack/workaround:
#             // it seems that Jupyter does not like very long lines
#             // so we split the data in chunks
#             var chunk_length = 100;
#             var pycb = "__colomoto_upload_name = " + JSON.stringify(obj.name) + "\n";
#             pycb += "__colomoto_upload_content = \\\n";
#             for (var i = 0; i < obj.content.length; i += chunk_length) {
#                 pycb += "\"" + obj.content.substr(i, chunk_length)+"\"\\\n"
#             }
#             pycb += "\n"
#             pycb += py_callback_name+"({'name':__colomoto_upload_name, 'content': __colomoto_upload_content})\n";
#             pycb += "del __colomoto_upload_name, __colomoto_upload_content"
#
#             IPython.notebook.kernel.execute(pycb, {iopub: {output: callback}});
#         };
#     })(f);
#     reader.readAsDataURL(f);
# }
#
# function resolve_function(tool_api, funcname) {
#     if (tool_api.hasOwnProperty(funcname)) {
#         return tool_api[funcname];
#     } else {
#         return window[funcname];
#     }
# }
#
# function colomoto_extension(Jupyter, ssid, name, menu, toolbar, tool_api) {
#
#     function insert_snippet_code(snippet) {
#         var cell = Jupyter.notebook.get_selected_cell();
#         Jupyter.notebook.edit_mode();
#         cell.code_mirror.replaceSelection(snippet, 'around');
#         //cell.focus_editor();
#     }
#
#     /**
#         from https://github.com/moble/jupyter_boilerplate/blob/master/main.js
#     */
#     function callback_insert_snippet (evt) {
#         // this (or event.currentTarget, see below) always refers to the DOM
#         // element the listener was attached to - see
#         // http://stackoverflow.com/questions/12077859
#         insert_snippet_code($(evt.currentTarget).data('snippet-code'));
#     }
#     function build_menu_element (menu_item_spec, direction) {
#         // Create the menu item html element
#         var element = $('<li/>');
#
#         if (typeof menu_item_spec == 'string') {
#             if (menu_item_spec != '---') {
#                 return element.html(menu_item_spec)
#                         .addClass('ui-state-disabled')
#                         .attr({"style": "padding:2px .4em"})
#                        ;
#             }
#             return element.addClass('divider');
#         }
#
#         var a = $('<a/>')
#             .attr('href', '#')
#             .html(menu_item_spec.name)
#             .appendTo(element);
#         if (menu_item_spec.hasOwnProperty('snippet')) {
#             var snippet = menu_item_spec.snippet;
#             if (typeof snippet == 'string' || snippet instanceof String) {
#                 snippet = [snippet];
#             }
#             a.attr({
#                 'title' : "", // Do not remove this, even though it's empty!
#                 'data-snippet-code' : snippet.join('\n'),
#             })
#             .on('click', callback_insert_snippet)
#             .addClass('snippet');
#         }
#         else if (menu_item_spec.hasOwnProperty('internal-link')) {
#             a.attr('href', menu_item_spec['internal-link']);
#         }
#         else if (menu_item_spec.hasOwnProperty('external-link')) {
#             a.empty();
#             a.attr('href', menu_item_spec['external-link']);
#             a.attr({
#                 'target' : '_blank',
#                 'title' : 'Opens in a new window',
#             });
#             $('<i class="fa fa-external-link menu-icon pull-right"/>').appendTo(a);
#             $('<span/>').html(menu_item_spec.name).appendTo(a);
#         }
#
#         if (menu_item_spec.hasOwnProperty('sub-menu')) {
#             element
#                 .addClass('dropdown-submenu')
#                 .toggleClass('dropdown-submenu-left', direction === 'left');
#             var sub_element = $('<ul class="dropdown-menu"/>')
#                 .toggleClass('dropdown-menu-compact', menu_item_spec.overlay === true) // For space-saving menus
#                 .appendTo(element);
#
#             var new_direction = (menu_item_spec['sub-menu-direction'] === 'left') ? 'left' : 'right';
#             for (var j=0; j<menu_item_spec['sub-menu'].length; ++j) {
#                 var sub_menu_item_spec = build_menu_element(menu_item_spec['sub-menu'][j], new_direction);
#                 if(sub_menu_item_spec !== null) {
#                     sub_menu_item_spec.appendTo(sub_element);
#                 }
#             }
#         }
#
#         return element;
#     }
#
#     function menu_setup (menu_item_specs, sibling, insert_before_sibling) {
#         for (var i=0; i<menu_item_specs.length; ++i) {
#             var menu_item_spec;
#             if (insert_before_sibling) {
#                 menu_item_spec = menu_item_specs[i];
#             } else {
#                 menu_item_spec = menu_item_specs[menu_item_specs.length-1-i];
#             }
#             var direction = (menu_item_spec['menu-direction'] == 'left') ? 'left' : 'right';
#             var menu_element = build_menu_element(menu_item_spec, direction);
#             // We need special properties if this item is in the navbar
#             if ($(sibling).parent().is('u
# <script type="text/javascript" id="colomoto-setup-4230461" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
#     var ginsim_jsapi = { action_upload_model: function() {
#         var cell = Jupyter.notebook.get_selected_cell();
#         cell.set_text('lrg = '+ginsim_jsapi.module_alias+'.upload()');
#         cell.focus_editor();
#     } };
#     colomoto_extension(Jupyter, "colomoto-setup-4230461", "ginsim", {"name": "GINsim", "sub-menu": [{"name": "Upload model", "snippet": ["lrg = ginsim.upload()"]}, {"name": "Load model", "snippet": ["lrg = ginsim.load(\"model.zginml\")"]}, "---", {"name": "Export to file", "sub-menu": [{"name": "MaBoSS (.bnd, .cfg)", "snippet": ["ginsim.service(\"maboss\").export(lrg, \"mymodel.bnd\")"]}]}, {"name": "Convert to tool", "sub-menu": [{"name": "bioLQM", "snippet": ["lqm = ginsim.to_biolqm(lrg)"]}, {"name": "MaBoSS", "snippet": ["masim = ginsim.to_maboss(lrg)"]}, {"name": "NuSMV", "snippet": ["smv = ginsim.to_nusmv(lrg)"]}, {"name": "Pint", "snippet": ["an = ginsim.to_pint(lrg)"]}]}, "---", {"name": " Display regulatory graph", "snippet": ["ginsim.show(lrg)"]}]}, [{"name": "upload", "setup": {"icon": "fa-upload", "help": "Upload model", "handler": "action_upload_model"}}], ginsim_jsapi);
#      }</script><style type="text/css">
#     #ginsim_menu {
#         color: blue;
#         background-color: white;
#     }
#
#     div#ginsim-toolbar:before {
#         content: "GINsim";
#         float: left;
#         margin-left: 1em;
#         margin-right: 1em;
#         margin-top: 0.2em;
#     }
#     div#ginsim-toolbar,
#     div#ginsim-toolbar button {
#         color: blue;
#     }
#     </style>
# <script type="text/javascript" id="colomoto-setup-9827550" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
#     var minibn_jsapi = {  };
#     colomoto_extension(Jupyter, "colomoto-setup-9827550", "minibn", null, null, minibn_jsapi);
#      }</script>

# %% [markdown]
# # MvReBnet: method for the identification of Multi-valued Refinements of Boolean network model

# %% [markdown]
# ### Model loading
# Loading of the BN model and any mutation of interest

# %%
model_name = input("Enter the name of the model: \n") # Name of the model
# Out:
# Enter the name of the model:
#  ML

# %%
from inputs import * # Python file with mutation, inits and names attrs

# %%
# BN model
primes = {}
primes["ASYN"] = file_exchange.bnet2primes("ASYN.bnet") # Asynchronous model
lqm = biolqm.load("ASYN.bnet")
bna = biolqm.to_minibn(lqm)
mbn = mpbn.MPBooleanNetwork(bna) # Most permissive model

# %%
# Mutation in the model
for g, v in mutations.items():
    prime_implicants.create_constants(primes["ASYN"], {g:v})
    mbn[g] = v

# %%
# Model visualization
bn = biolqm.to_ginsim(lqm)
ginsim.show(bn)
# Out:
# <img class="unconfined" width="561px" src="data:image/svg+xml;base64,...">

# %% [markdown]
# ### Identification of the attractors
#
# Determination of the attractors of the BN model under the asynchronous and most permissive scheme

# %%
# Separation of the stable states and cyclic attractors.
at_asyn = attractors.compute_attractors(primes["ASYN"], "asynchronous")
at_mp = list(mbn.attractors())

stable_states = {}
cyclic_attractors = {}

stable_states["ASYN"] = {i: attractor for i, attractor in enumerate(at_asyn["attractors"]) if not attractor["is_cyclic"]}
cyclic_attractors["ASYN"] = {i: attractor for i, attractor in enumerate(at_asyn["attractors"]) if attractor["is_cyclic"]}

stable_states["MP"] = {i: attractor for i, attractor in enumerate(at_mp) if "*" not in attractor.values()}
cyclic_attractors["MP"] = {i: attractor for i, attractor in enumerate(at_mp) if "*" in attractor.values()}
# Out:
# INFO attractors.completeness(..)
# INFO created /tmp/pyboolnet_mn9osnkg
# INFO yes
# INFO  working on minimal trapspace 1/5: 000000100010011
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=15, update=asynchronous, length=150, attempts=10
# INFO trial 0
# INFO start: 000000100010011
# INFO end: 000000100010011
# INFO created /tmp/pyboolnet_mgy02tbf
# INFO is attractor state
# INFO  working on minimal trapspace 2/5: 000100000000100
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=15, update=asynchronous, length=150, attempts=10
# INFO trial 0
# INFO start: 000100000000100
# INFO end: 000100000000100
# INFO created /tmp/pyboolnet_2xofm9tz
# INFO is attractor state
# INFO  working on minimal trapspace 3/5: 000000000000000
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=15, update=asynchronous, length=150, attempts=10
# INFO trial 0
# INFO start: 000000000000000
# INFO end: 000000000000000
# INFO created /tmp/pyboolnet_njsj7ngk
# INFO is attractor state
# INFO  working on minimal trapspace 4/5: 000001100000011
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=15, update=asynchronous, length=150, attempts=10
# INFO trial 0
# INFO start: 000001100000011
# INFO end: 000001100000011
# INFO created /tmp/pyboolnet___fzi6dq
# INFO is attractor state
# INFO  working on minimal trapspace 5/5: 000000011000100
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=15, update=asynchronous, length=150, attempts=10
# INFO trial 0
# INFO start: 000000011000100
# INFO end: 000000011000100
# INFO created /tmp/pyboolnet_6z13t43j
# INFO is attractor state

# %%
if not cyclic_attractors["ASYN"] and not cyclic_attractors["MP"]:
    print("There are no cyclic attractors")
elif cyclic_attractors["ASYN"] == cyclic_attractors["MP"]:
    print("The cyclic attractors are identical")
else:
    print("The cyclic attractors are different")
# Out:
# There are no cyclic attractors

# %% [markdown]
# ## Propriety P: Asyncrhonous vs M.p.
#
# In this part, we assess whether the most permissive dynamics can capture a specific reachability property, P, of interest. P may either be an increase in the sizes of the basins of attraction or a precise reachability observable only in the most permissive dynamics. In the case of precise reachability, a file dictating the desired reachability in the following format is necessary.

# %%
# Functions used in the notebook
def bool_to_jmp(state, m): # Translation of a Boolean state to a partial Jm.p. state    
    states = copy.deepcopy(state)
    if m not in ["MP", "ASYN"]:
        for k in m.split("_"):
            if k in states:
                v = states[k]
                for suffix in ['_a', '_b', '_c']:
                    states[k + suffix] = v
                del states[k]
    return states

def bool_to_mv(state, m): # Translation of a Boolean state to a partial Jm.p. state    
    states = copy.deepcopy(state)
    if m not in ["MP", "ASYN"]:
        for k in m.split("_"):
            if k in states:
                v = states[k]
                for suffix in ['_b1', '_b2']:
                    states[k + suffix] = v
                del states[k]
    return states

def sboa_df(ss_asyn, models): # Data frame of the sizes of the basins of attraction of fixed point
    rnames = [ss_asyn[i]["state"]['str'] for i in range(len(ss_asyn))]
    df = pd.DataFrame(columns=models, index=rnames)
    return df

def basin(attractors, primes, lm, model, sboa_df): # Calculates the basin of attraction
    init = {}
    for m in model[:-1]:
        if m == "ASYN":
            init[m] = "INIT TRUE"
        else:
            if lm == "mp":
                mn = [k[:-2] for k, _ in primes[m].items() if k.endswith("_c")]
                if mn:
                    clause = [f"({n}_a&{n}_b&{n}_c) | (!{n}_a&!{n}_b&!{n}_c)" for n in mn]
                    init[m] = f"INIT ({' & '.join(clause)})"
            else: 
                mn = [k[:-3] for k, _ in primes[m].items() if k.endswith("_b2")]
                if mn:
                    clause = [f"({n}_b1&{n}_b2) | (!{n}_b1&!{n}_b2)" for n in mn]
                    init[m] = f"INIT ({' & '.join(clause)})"

    for m in model[:-1]:
        if primes.get(m) is not None:
            size = len(primes["ASYN"])
            for i in range(len(attractors)):
                if lm == "mp":
                    attr = bool_to_jmp(attractors[i]["state"]["dict"], m)
                else: attr = bool_to_mv(attractors[i]["state"]["dict"], m)
                s = state_space.state2str(attr)
                specification = f"CTLSPEC EF({model_checking.subspace2proposition(primes[m], attr)})"
                _, accepting_states = model_checking.model_checking(primes[m],
                                                                    "asynchronous",
                                                                    init[m], 
                                                                    specification, 
                                                                    enable_accepting_states=True)
                sboa = accepting_states["INITACCEPTING_SIZE"]/2**size*100
                sboa_df.loc[s, m] = sboa

    for i in range(len(attractors)):
        states = list(mbn.reachable_from(attractors[i]["state"]["dict"], reversed= True))
        s = attractors[i]["state"]["str"]
        sboa_df.loc[s,"MP"] = len(states)/2**(size)*100          

    return sboa_df

def mc(primes, lm, model, mbn,inits, attrs): # Test the attractors reachability from the given initial states
    init = {}
    for m in model[:-1]:
        init[m] = {}
        if m == "ASYN":
            for n, i in inits.items():
                init[m][n] = f"INIT {subspace2proposition(primes[m], i)}"
        else:
            for n, i in inits.items():
                temp = copy.deepcopy(inits) 
                if lm == "mp":
                    init[m][n] = f"INIT {subspace2proposition(primes[m], bool_to_jmp(temp[n],m))}"
                else: init[m][n] = f"INIT {subspace2proposition(primes[m], bool_to_mv(temp[n],m))}"


    answer = {}
    for m in model[:-1]:
        answer[m] = {}
        for i in inits.keys():
            answer[m][i] = []
            for j in attrs.keys():
                if m == "ASYN":
                     attr = attrs[j]
                else:
                     if lm == "mp":
                         attr = bool_to_jmp(copy.deepcopy(attrs[j]),m)
                     else: attr = bool_to_mv(copy.deepcopy(attrs[j]),m)
                 
                specification = f"CTLSPEC EF({model_checking.subspace2proposition(primes[m],attr)})"
                res = model_checking.model_checking(primes[m],
                                                   "asynchronous",
                                                   init[m][i],
                                                   specification)
                n = j+" : "+str(res)
                answer[m][i].append(n)

    
    answer["MP"] = {}
    for n, i in inits.items():
        answer["MP"][n] = []
        for j in attrs.keys():
            res = j+" : "+str(mbn.reachability(i, attrs[j]))
            answer["MP"][n].append(res)
            
    return answer

# %%
# Checking if the basins of attraction are different
df = sboa_df(stable_states["ASYN"], ["ASYN","MP"])
basin_asyn_vs_mp = basin(stable_states["ASYN"], primes, "mp", ["ASYN","MP"], df)
basin_asyn_vs_mp.to_csv(model_name+"_MvReBnet_basin_asyn_vs_mp_basin_sizes.csv")
# Out:
# INFO created /tmp/pyboolnet_yhywlc0i
# INFO created /tmp/pyboolnet_kumfv0z4
# INFO created /tmp/pyboolnet_dje4af9h
# INFO created /tmp/pyboolnet_603rjwf0
# INFO created /tmp/pyboolnet_aok_wid8

# %%
if not (basin_asyn_vs_mp["ASYN"].all == basin_asyn_vs_mp["MP"].all):
    print("The most permissive dynamics shows an increase in the sizes of the basin of attraction")
else:
    print("No difference in the sizes of basin of attraction")
# Out:
# The most permissive dynamics shows an increase in the sizes of the basin of attraction

# %%
basin_asyn_vs_mp
# Out:
#                       ASYN         MP
# 000000000000000   61.71875  81.982422
# 000000011000100   16.40625   63.28125
# 000000100010011  69.604492  86.083984
# 000001100000011   97.65625    98.4375
# 000100000000100  70.483398  78.271484

# %%
# Checking if a reahcability of interest is recovered by the most permissive scheme
mc_asyn_vs_mp = mc(primes, "mp", ["ASYN","MP"], mbn, inits, attrs)
# Out:
# INFO created /tmp/pyboolnet_w4f00nep
# INFO created /tmp/pyboolnet_9zmloe_k
# INFO created /tmp/pyboolnet_ku8trgi9
# INFO created /tmp/pyboolnet_snj1hovf
# INFO created /tmp/pyboolnet_wgc55c07
# INFO created /tmp/pyboolnet_nt0zimfs
# INFO created /tmp/pyboolnet_lx3o8fo7
# INFO created /tmp/pyboolnet__l4f8m8n
# INFO created /tmp/pyboolnet_kunfkpzi
# INFO created /tmp/pyboolnet_o3vpgyzg
# INFO created /tmp/pyboolnet_f7ewnp65
# INFO created /tmp/pyboolnet_ziqbshep
# INFO created /tmp/pyboolnet_okda18ec
# INFO created /tmp/pyboolnet_myz7_xp8
# INFO created /tmp/pyboolnet_56k6hdrv
# INFO created /tmp/pyboolnet_i0n0uq9v
# INFO created /tmp/pyboolnet_hldv622x
# INFO created /tmp/pyboolnet_307hkzcc
# INFO created /tmp/pyboolnet_s3zp76td
# INFO created /tmp/pyboolnet_sacu5alq
# The most permissive dynamics captures the reachability of interest, not captured by the asynchronous dynamics

# %%
if mc_asyn_vs_mp["ASYN"] != mc_asyn_vs_mp["MP"]:
    print("The most permissive dynamics captures the reachability of interest, not captured by the asynchronous dynamics")
else: print("No difference for the reachability of interest")
# Out:
# The most permissive dynamics captures the reachability of interest, not captured by the asynchronous dynamics

# %% [markdown]
# ### Propriety P: M.p vs Partial Jm.p.
#
# In this part, we assess which partial Jm.p. dynamics can capture the reachability property P.

# %%
# List of admissible np nodes: no output or auto-inhibited nodes
# Extract nodes with self-inhibition from 'primes["ASYN"]'
self_in = [i for i in primes["ASYN"] if f"!{i}" in str(bna[i])]
# Find outputs in 'primes["ASYN"]'
outputs = prime_implicants.find_outputs(primes['ASYN'])
# Filter out nodes that are neither outputs nor have self-inhibition
mp_nodes = [item for item in primes['ASYN'] if item not in outputs and item not in self_in]

# %%
nb_mp_nodes = input("Enter the number of mp node(s) you want to test: \n")
# Out:
# Enter the number of mp node(s) you want to test:
#  4

# %%
# List of sets J depending on the size defined
jsets = list(combinations(mp_nodes, int(nb_mp_nodes))) # Combinations of mp nodes
models = ["_".join(map(str, i)) for i in jsets]
models.insert(0, "ASYN")
models.append("MP")

# %% [markdown]
# Use the list "jsets" as input to generate the partial mp dynamics in Biolqm. The resulting models should be in the same directory.

# %%
# jm.p. model loading
for m in models[1:-1]:
    path = m + "_mp.bnet"
    if os.path.isfile(path) == True:
        primes[m] = file_exchange.bnet2primes(path)
        for g, v in mutations.items():
            if {g}.issubset(m.split("_")) == True:
                prime_implicants.create_constants(primes[m], {g+"_a":v, g+"_b":v, g+"_c":v})
            else:
                prime_implicants.create_constants(primes[m], {g:v})

# %%
# Sizes of the basin of attraction under the partial most permissive scheme
df = sboa_df(stable_states["ASYN"], models[1:-1])
basin_sizes = basin(stable_states["ASYN"], primes, "mp", models[1:-1], df)
basin_sizes.to_csv(model_name+"_MvReBnet_"+nb_mp_nodes+"mp_basin_sizes.csv")
# Out:
# INFO created /tmp/pyboolnet_9pkpop1v
# INFO created /tmp/pyboolnet_ajdvqxus
# INFO created /tmp/pyboolnet_e907jduu
# INFO created /tmp/pyboolnet_43av6u5i
# INFO created /tmp/pyboolnet_ugif2yie
# INFO created /tmp/pyboolnet_36gm2872
# INFO created /tmp/pyboolnet_zzsi93xp
# INFO created /tmp/pyboolnet_hh6pg60y
# INFO created /tmp/pyboolnet_1dzq2nai
# INFO created /tmp/pyboolnet_hork4mcu
# INFO created /tmp/pyboolnet_be_fx6a2
# INFO created /tmp/pyboolnet_hzbb_laf
# INFO created /tmp/pyboolnet_uu1rgde7
# INFO created /tmp/pyboolnet_twlz7h8w
# INFO created /tmp/pyboolnet_nfq3tn7t
# INFO created /tmp/pyboolnet_brfq73xx
# INFO created /tmp/pyboolnet_0i3tvk3t
# INFO created /tmp/pyboolnet_jouclqdq
# INFO created /tmp/pyboolnet_rgxp3x_u
# INFO created /tmp/pyboolnet_pnp84rdu
# INFO created /tmp/pyboolnet_ap4intgh
# INFO created /tmp/pyboolnet_ob1st72w
# INFO created /tmp/pyboolnet_d7o0rmfz
# INFO created /tmp/pyboolnet_731sz0lw
# INFO created /tmp/pyboolnet_ibo_nhz3
# INFO created /tmp/pyboolnet_n79f6cgp
# INFO created /tmp/pyboolnet_i_8n0gao
# INFO created /tmp/pyboolnet_4c5a8yve
# INFO created /tmp/pyboolnet_rnjgb0ow
# INFO created /tmp/pyboolnet_67mvjjac
# INFO created /tmp/pyboolnet_h3of7n5o
# INFO created /tmp/pyboolnet_rb7her8m
# INFO created /tmp/pyboolnet_1zees8lb
# INFO created /tmp/pyboolnet_0822oexk
# INFO created /tmp/pyboolnet_0zw0978k
# INFO created /tmp/pyboolnet_5pygiqas
# INFO created /tmp/pyboolnet_oqgvpqq6
# INFO created /tmp/pyboolnet_gh2m3d7j
# INFO created /tmp/pyboolnet_p9toj5ou
# INFO created /tmp/pyboolnet_6hq6q08j
# INFO created /tmp/pyboolnet_byy9ugs9
# INFO created /tmp/pyboolnet_hmvs2uws
# INFO created /tmp/pyboolnet_x2j148t4
# INFO created /tmp/pyboolnet_63w2agil
# INFO created /tmp/pyboolnet_l2mb_8if
# INFO created /tmp/pyboolnet_6kdedw_i
# INFO created /tmp/pyboolnet_ys5ff3hd
# INFO created /tmp/pyboolnet_1y13ngkd
# INFO created /tmp/pyboolnet_e6cscug9
# INFO created /tmp/pyboolnet_k3mp_bws
# INFO created /tmp/pyboolnet_5uilm2vk
# INFO created /tmp/pyboolnet_a4_j_ggj
# INFO created /tmp/pyboolnet_rvoosdty
# INFO created /tmp/pyboolnet_4yb85lr2
# INFO created /tmp/pyboolnet_nxrtx1qc

# %%
# Checking if a reachability of interest is recovered under the partial most permissive scheme
answer = mc(primes, "mp", models, mbn, inits, attrs)
with open(model_name+"_MvReBnet_"+nb_mp_nodes+'model_checking.txt', 'w') as f:
    print(answer, file=f)
# Out:
# INFO created /tmp/pyboolnet_obw5scgp
# INFO created /tmp/pyboolnet_4ijzz3gg
# INFO created /tmp/pyboolnet_kwyuh5q6
# INFO created /tmp/pyboolnet_il9tkmtv
# INFO created /tmp/pyboolnet_hupesnnn
# INFO created /tmp/pyboolnet_okyzklc1
# INFO created /tmp/pyboolnet_nl9pxv3m
# INFO created /tmp/pyboolnet_syuyf57f
# INFO created /tmp/pyboolnet_a9aqu4ba
# INFO created /tmp/pyboolnet_a8ifkf4d
# INFO created /tmp/pyboolnet_ohyq36ut
# INFO created /tmp/pyboolnet_hadc64pe
# INFO created /tmp/pyboolnet_9r5iw0lp
# INFO created /tmp/pyboolnet_f1vqsy1z
# INFO created /tmp/pyboolnet_ff0c4ctz
# INFO created /tmp/pyboolnet_6wxgyy0f
# INFO created /tmp/pyboolnet_cu8bj09y
# INFO created /tmp/pyboolnet_yf2ipi4o
# INFO created /tmp/pyboolnet_kujhev74
# INFO created /tmp/pyboolnet__azikit5
# INFO created /tmp/pyboolnet_dvhc5e2x
# INFO created /tmp/pyboolnet_11vuh67v
# INFO created /tmp/pyboolnet_t7ix0x0l
# INFO created /tmp/pyboolnet_5rktpqsf
# INFO created /tmp/pyboolnet_yugs3ihs
# INFO created /tmp/pyboolnet_prmbtmgr
# INFO created /tmp/pyboolnet_s2hh_6gi
# INFO created /tmp/pyboolnet_bf8rpupk
# INFO created /tmp/pyboolnet_54snyg95
# INFO created /tmp/pyboolnet_rfifpquc
# INFO created /tmp/pyboolnet_xh7al8u3
# INFO created /tmp/pyboolnet_0o4qi1s8
# INFO created /tmp/pyboolnet_4rnonad2
# INFO created /tmp/pyboolnet_ykcy_r3i
# INFO created /tmp/pyboolnet_vk2s0vcy
# INFO created /tmp/pyboolnet_9dqzva_w
# INFO created /tmp/pyboolnet_pzz1e_5t
# INFO created /tmp/pyboolnet_rwaledbz
# INFO created /tmp/pyboolnet_wkkciw9i
# INFO created /tmp/pyboolnet_o7519lwt
# INFO created /tmp/pyboolnet_uyd8_5ls
# INFO created /tmp/pyboolnet_ap23_5rx
# INFO created /tmp/pyboolnet_9pk1qzr9
# INFO created /tmp/pyboolnet_r1jgza10
# INFO created /tmp/pyboolnet_w14myp17
# INFO created /tmp/pyboolnet_qmxloh7x
# INFO created /tmp/pyboolnet_3wbpk6k4
# INFO created /tmp/pyboolnet_mfkofgkl
# INFO created /tmp/pyboolnet_9r0ayanl
# INFO created /tmp/pyboolnet_zs0ylyp2
# INFO created /tmp/pyboolnet_xfalo50p
# INFO created /tmp/pyboolnet_nn1jwbz3
# INFO created /tmp/pyboolnet_fdqkfam3
# INFO created /tmp/pyboolnet_4iyop34d
# INFO created /tmp/pyboolnet_2hw7nrs3
# INFO created /tmp/pyboolnet_kx4xd78z
# INFO created /tmp/pyboolnet_molgic4i
# INFO created /tmp/pyboolnet__envw4yb
# INFO created /tmp/pyboolnet_cb56e9dx
# INFO created /tmp/pyboolnet_fozo4yom
# INFO created /tmp/pyboolnet_3k1mpmos
# INFO created /tmp/pyboolnet_d3pywdy2
# INFO created /tmp/pyboolnet_hcrdisnz
# INFO created /tmp/pyboolnet__vocyv24
# INFO created /tmp/pyboolnet_neoyibfd
# INFO created /tmp/pyboolnet_w_xb2pk2
# INFO created /tmp/pyboolnet_qtyap6z2
# INFO created /tmp/pyboolnet_1upm035s
# INFO created /tmp/pyboolnet_f6mnovub
# INFO created /tmp/pyboolnet_yfr_ksx9
# INFO created /tmp/pyboolnet_z7mrabud
# INFO created /tmp/pyboolnet_q80xe8cs
# INFO created /tmp/pyboolnet_diuk4ath
# INFO created /tmp/pyboolnet_sxe9xcse
# INFO created /tmp/pyboolnet_ca587z45
# INFO created /tmp/pyboolnet_p7qpo4k2
# INFO created /tmp/pyboolnet_xpr0v3le
# INFO created /tmp/pyboolnet_ebx7h8vs
# INFO created /tmp/pyboolnet_mt0az_r4
# INFO created /tmp/pyboolnet_6gomz2ug
# INFO created /tmp/pyboolnet_bmys9cgd
# INFO created /tmp/pyboolnet_3f05pafg
# INFO created /tmp/pyboolnet_t8ltj906
# INFO created /tmp/pyboolnet_kcsdnjbs
# INFO created /tmp/pyboolnet_jffyeou5
# INFO created /tmp/pyboolnet_h775lhke
# INFO created /tmp/pyboolnet_28j6qvty
# INFO created /tmp/pyboolnet_bs5d03wy
# INFO created /tmp/pyboolnet_45hm3swb
# INFO created /tmp/pyboolnet_qk6tdisx
# INFO created /tmp/pyboolnet_8mbi_1v4
# INFO created /tmp/pyboolnet_t9haiz3z
# INFO created /tmp/pyboolnet_q61vo_lb
# INFO created /tmp/pyboolnet_g2zts6ms
# INFO created /tmp/pyboolnet_dmrmzvcw
# INFO created /tmp/pyboolnet_x5wa_edr
# INFO created /tmp/pyboolnet_gy_t_maw
# INFO created /tmp/pyboolnet_4l32j_6f
# INFO created /tmp/pyboolnet_ua3xzffk
# INFO created /tmp/pyboolnet_zvrm_msp
# INFO created /tmp/pyboolnet_12xnnc9_
# INFO created /tmp/pyboolnet_jljrn8in
# INFO created /tmp/pyboolnet_80cvz076
# INFO created /tmp/pyboolnet_34nxubkb
# INFO created /tmp/pyboolnet_2uydqrav
# INFO created /tmp/pyboolnet_dqyw_k_z
# INFO created /tmp/pyboolnet_npwwqrfp
# INFO created /tmp/pyboolnet_78jn0hqa
# INFO created /tmp/pyboolnet_wi5bt4wv
# INFO created /tmp/pyboolnet_l6rirc6t
# INFO created /tmp/pyboolnet_fi0_d3es
# INFO created /tmp/pyboolnet_k7_ihmkk
# INFO created /tmp/pyboolnet_bsxh5bw_
# INFO created /tmp/pyboolnet_mt4miczs
# INFO created /tmp/pyboolnet_4hlbrufx
# INFO created /tmp/pyboolnet_3gqko2zc
# INFO created /tmp/pyboolnet_v2f0s_sl
# INFO created /tmp/pyboolnet_lyw7t5mo
# INFO created /tmp/pyboolnet_3yncct90
# INFO created /tmp/pyboolnet_r0ho_ugy
# INFO created /tmp/pyboolnet_5kkr9tzp
# INFO created /tmp/pyboolnet_d3ychl7n
# INFO created /tmp/pyboolnet_yci1zeax
# INFO created /tmp/pyboolnet_pm6ljdhy
# INFO created /tmp/pyboolnet_89iv0p1t
# INFO created /tmp/pyboolnet_0zialgb4
# INFO created /tmp/pyboolnet_17781n01
# INFO created /tmp/pyboolnet_wlkkvbri
# INFO created /tmp/pyboolnet_ucb98frd
# INFO created /tmp/pyboolnet_2so1dqua
# INFO created /tmp/pyboolnet_gqsp73mt
# INFO created /tmp/pyboolnet_h3f57hoh
# INFO created /tmp/pyboolnet_qi9foht5
# INFO created /tmp/pyboolnet_mbg8eh31
# INFO created /tmp/pyboolnet_ogw2r744
# INFO created /tmp/pyboolnet_36n8gett
# INFO created /tmp/pyboolnet_l53rbm0l
# INFO created /tmp/pyboolnet_vhhby2bk
# INFO created /tmp/pyboolnet_6fql22hu
# INFO created /tmp/pyboolnet_9m1va4tk
# INFO created /tmp/pyboolnet_m4qufqur
# INFO created /tmp/pyboolnet_v9qisik2
# INFO created /tmp/pyboolnet_4z509ibh
# INFO created /tmp/pyboolnet_2algxcc2
# INFO created /tmp/pyboolnet_898gx_wh
# INFO created /tmp/pyboolnet_hujdabfu
# INFO created /tmp/pyboolnet_xo7tw46n
# INFO created /tmp/pyboolnet_jyc3pq_7
# INFO created /tmp/pyboolnet_8s_qekyx
# INFO created /tmp/pyboolnet_mbbrr_su
# INFO created /tmp/pyboolnet_dde9g3g7
# INFO created /tmp/pyboolnet_14x0p2pk
# INFO created /tmp/pyboolnet_95ykoghj
# INFO created /tmp/pyboolnet_z31hnirx
# INFO created /tmp/pyboolnet_zl8q2gqb
# INFO created /tmp/pyboolnet_vjbi9nbv
# INFO created /tmp/pyboolnet_5kfiqgjs
# INFO created /tmp/pyboolnet_1na5zg5q
# INFO created /tmp/pyboolnet_0kq3a641
# INFO created /tmp/pyboolnet_7zxsvkqb
# INFO created /tmp/pyboolnet_sec309r2
# INFO created /tmp/pyboolnet_uv7a64s3
# INFO created /tmp/pyboolnet_36iamxzb
# INFO created /tmp/pyboolnet_lkt6immf
# INFO created /tmp/pyboolnet_d2mga46s
# INFO created /tmp/pyboolnet_sb3ube7b
# INFO created /tmp/pyboolnet_fkom8ti1
# INFO created /tmp/pyboolnet_w4g8rh7y
# INFO created /tmp/pyboolnet_cahoav0t
# INFO created /tmp/pyboolnet_vrl_kawr
# INFO created /tmp/pyboolnet_v9ii9xkh
# INFO created /tmp/pyboolnet_cjff49e8
# INFO created /tmp/pyboolnet_3ktu_2mm
# INFO created /tmp/pyboolnet_oj497mfi
# INFO created /tmp/pyboolnet_v95h6ol9
# INFO created /tmp/pyboolnet_zmorjrfu
# INFO created /tmp/pyboolnet_dkf8oo13
# INFO created /tmp/pyboolnet_nnhx51uh
# INFO created /tmp/pyboolnet_ujn4fzg_
# INFO created /tmp/pyboolnet_6ey3fx37
# INFO created /tmp/pyboolnet_9552oudr
# INFO created /tmp/pyboolnet_u7isyq0h
# INFO created /tmp/pyboolnet_trxssp9s
# INFO created /tmp/pyboolnet_pt2kkp9c
# INFO created /tmp/pyboolnet_c57_fr3j
# INFO created /tmp/pyboolnet_elqh9nyw
# INFO created /tmp/pyboolnet_ecqosnzx
# INFO created /tmp/pyboolnet_8en0ojbv
# INFO created /tmp/pyboolnet_5kmv1tgy
# INFO created /tmp/pyboolnet_4zk9b8f4
# INFO created /tmp/pyboolnet_1jpi88ok
# INFO created /tmp/pyboolnet_568468zq
# INFO created /tmp/pyboolnet_hqn2v7zx
# INFO created /tmp/pyboolnet_5wu6meyy
# INFO created /tmp/pyboolnet_q8dfych3
# INFO created /tmp/pyboolnet_aq2c7en3
# INFO created /tmp/pyboolnet_apmkv45n
# INFO created /tmp/pyboolnet__1qojcp3
# INFO created /tmp/pyboolnet_exxugenv
# INFO created /tmp/pyboolnet_dmyjfo3e
# INFO created /tmp/pyboolnet_qnd2x8_0
# INFO created /tmp/pyboolnet_g0ybcwvz
# INFO created /tmp/pyboolnet_u8717_zp
# INFO created /tmp/pyboolnet_jt9r1s7s
# INFO created /tmp/pyboolnet_y9ikstl0
# INFO created /tmp/pyboolnet_g0q_phhq
# INFO created /tmp/pyboolnet_7uvbnu4m
# INFO created /tmp/pyboolnet_hufuwi31
# INFO created /tmp/pyboolnet_bsk3ar7n
# INFO created /tmp/pyboolnet_bq90jbpz
# INFO created /tmp/pyboolnet_i576z1l0
# INFO created /tmp/pyboolnet_abtqtgvk
# INFO created /tmp/pyboolnet_3q380bsr
# INFO created /tmp/pyboolnet_9wid82s0
# INFO created /tmp/pyboolnet_5vr58vdh
# INFO created /tmp/pyboolnet_ioqdsxnn
# INFO created /tmp/pyboolnet_6_ocgoi7
# INFO created /tmp/pyboolnet_80ivwdsk
# INFO created /tmp/pyboolnet_xt9itl6o
# INFO created /tmp/pyboolnet_zs83qc0i
# INFO created /tmp/pyboolnet_cefwar08
# INFO created /tmp/pyboolnet_pdr92idy
# INFO created /tmp/pyboolnet_iejbrkqe
# INFO created /tmp/pyboolnet__nsnhmt_
# INFO created /tmp/pyboolnet_10kmhenu
# INFO created /tmp/pyboolnet_2afvsw6y
# INFO created /tmp/pyboolnet_w_6lyv1j
# INFO created /tmp/pyboolnet_syqehqyx
# INFO created /tmp/pyboolnet_mda9jft7
# INFO created /tmp/pyboolnet_3gt3axl4
# INFO created /tmp/pyboolnet_2g1l7ypi
# INFO created /tmp/pyboolnet_s6xc_9ka
# INFO created /tmp/pyboolnet_eig2tz2r
# INFO created /tmp/pyboolnet_1dhxxa8i
# INFO created /tmp/pyboolnet_nufz30zz
# INFO created /tmp/pyboolnet_vyt8ji10
# INFO created /tmp/pyboolnet_tw5e67uw
# INFO created /tmp/pyboolnet_a_c0ugqk
# INFO created /tmp/pyboolnet_gynv13v3
# INFO created /tmp/pyboolnet_vxnsp831
# INFO created /tmp/pyboolnet_1vl_ta2h
# INFO created /tmp/pyboolnet_hjwwgdmz
# INFO created /tmp/pyboolnet_u40tvzy0
# INFO created /tmp/pyboolnet_m6w1xk2n
# INFO created /tmp/pyboolnet_i8b86esz
# INFO created /tmp/pyboolnet_ifb6ju4j
# INFO created /tmp/pyboolnet_p1yfeb6b
# INFO created /tmp/pyboolnet_00q2c7xl
# INFO created /tmp/pyboolnet_xxya8n5y
# INFO created /tmp/pyboolnet_4zzmkes1
# INFO created /tmp/pyboolnet_hlfs_0hq
# INFO created /tmp/pyboolnet_gxts4095
# INFO created /tmp/pyboolnet_4107awlo
# INFO created /tmp/pyboolnet_m8nclm1s
# INFO created /tmp/pyboolnet_p1a2b10w
# INFO created /tmp/pyboolnet_kuiii9tf
# INFO created /tmp/pyboolnet_tjoe4a0s
# INFO created /tmp/pyboolnet_4nxhc8hh
# INFO created /tmp/pyboolnet_60kfbedd
# INFO created /tmp/pyboolnet_7qrdu577
# INFO created /tmp/pyboolnet_cgh509fm
# INFO created /tmp/pyboolnet_ha75bo9p
# INFO created /tmp/pyboolnet_s2g72dte
# INFO created /tmp/pyboolnet_zhiesagj
# INFO created /tmp/pyboolnet_533zmb1d
# INFO created /tmp/pyboolnet_gspgzone
# INFO created /tmp/pyboolnet_2o_59ut3
# INFO created /tmp/pyboolnet_66hcmkgz
# INFO created /tmp/pyboolnet_8sj_rqb1
# INFO created /tmp/pyboolnet_h66e9rs5
# INFO created /tmp/pyboolnet_udq_7qk0
# INFO created /tmp/pyboolnet_isgcynpf
# INFO created /tmp/pyboolnet_h0try3zc
# INFO created /tmp/pyboolnet_siqxql4o
# INFO created /tmp/pyboolnet_ov9kb3km
# INFO created /tmp/pyboolnet_0iza0q2l
# INFO created /tmp/pyboolnet_z0vgb6xx
# INFO created /tmp/pyboolnet_dbn226hk
# INFO created /tmp/pyboolnet_7540fit1
# INFO created /tmp/pyboolnet_zeidkwft
# INFO created /tmp/pyboolnet_3_c1l3jx
# INFO created /tmp/pyboolnet_d26regtm
# INFO created /tmp/pyboolnet_gw5g4wl0
# INFO created /tmp/pyboolnet_3j2e8lrf
# INFO created /tmp/pyboolnet_cqa5_wrf
# INFO created /tmp/pyboolnet__j2nl2c0
# INFO created /tmp/pyboolnet_jdidwjgq
# INFO created /tmp/pyboolnet_ia89ovym
# INFO created /tmp/pyboolnet_sqknu3ch
# INFO created /tmp/pyboolnet_b37u7hhf
# INFO created /tmp/pyboolnet_3beoljpe
# INFO created /tmp/pyboolnet_wqp5dl9w
# INFO created /tmp/pyboolnet_ebuuc4l7
# INFO created /tmp/pyboolnet_gcfm505_
# INFO created /tmp/pyboolnet_xgrzzco9
# INFO created /tmp/pyboolnet_542cutcn
# INFO created /tmp/pyboolnet_izxxnwm6
# INFO created /tmp/pyboolnet_j6ueig2q
# INFO created /tmp/pyboolnet_4e11120f
# INFO created /tmp/pyboolnet_yvx3txnf
# INFO created /tmp/pyboolnet_knnl9mvv
# INFO created /tmp/pyboolnet_dvmj91lo
# INFO created /tmp/pyboolnet_7n0d6lf8
# INFO created /tmp/pyboolnet_3dhk0o5y
# INFO created /tmp/pyboolnet_2rfipgo0
# INFO created /tmp/pyboolnet_9w_d807u
# INFO created /tmp/pyboolnet_l2vzorjx
# INFO created /tmp/pyboolnet_wd7zjahg
# INFO created /tmp/pyboolnet_y1j5g0ui
# INFO created /tmp/pyboolnet_h4ixr2b_
# INFO created /tmp/pyboolnet_yntdkrb4
# INFO created /tmp/pyboolnet_ci8fcjab
# INFO created /tmp/pyboolnet_wryfudzk
# INFO created /tmp/pyboolnet_jrqjnzs_
# INFO created /tmp/pyboolnet_3qz39ouk
# INFO created /tmp/pyboolnet_njn9kzei
# INFO created /tmp/pyboolnet_9nmyp_uw
# INFO created /tmp/pyboolnet_petnlv5y
# INFO created /tmp/pyboolnet_kq9hhlhd
# INFO created /tmp/pyboolnet_r94bvai5
# INFO created /tmp/pyboolnet_q_40h1hy
# INFO created /tmp/pyboolnet_fs5dvlue
# INFO created /tmp/pyboolnet_v281vn7q
# INFO created /tmp/pyboolnet_8e3s4jgh
# INFO created /tmp/pyboolnet_nm5tc18n
# INFO created /tmp/pyboolnet_m3w412py
# INFO created /tmp/pyboolnet_xj5tsxgm
# INFO created /tmp/pyboolnet_mqgpmp32
# INFO created /tmp/pyboolnet_jyhlazk5
# INFO created /tmp/pyboolnet_7knj_bov
# INFO created /tmp/pyboolnet_2j1w9jt4
# INFO created /tmp/pyboolnet_rae72wju
# INFO created /tmp/pyboolnet_oh0_no24
# INFO created /tmp/pyboolnet_wjowzn8t
# INFO created /tmp/pyboolnet_y6ee9qt1
# INFO created /tmp/pyboolnet_iuluj8ol
# INFO created /tmp/pyboolnet_gnf3znkz
# INFO created /tmp/pyboolnet_12_kx8uu
# INFO created /tmp/pyboolnet_arn569mz
# INFO created /tmp/pyboolnet_g_xfgozz
# INFO created /tmp/pyboolnet_s8kn4pzk
# INFO created /tmp/pyboolnet_tj3cabru
# INFO created /tmp/pyboolnet_5szicjhw
# INFO created /tmp/pyboolnet_i72vyzi3
# INFO created /tmp/pyboolnet_9yo8fxlf
# INFO created /tmp/pyboolnet_adyzd56m
# INFO created /tmp/pyboolnet_g2rg8dly
# INFO created /tmp/pyboolnet_pe3lftrq
# INFO created /tmp/pyboolnet_4_gog_su
# INFO created /tmp/pyboolnet_tzzktva0
# INFO created /tmp/pyboolnet_el35rjdt
# INFO created /tmp/pyboolnet_wa3gkwmx
# INFO created /tmp/pyboolnet_u29x71fb
# INFO created /tmp/pyboolnet_7lipz5af
# INFO created /tmp/pyboolnet_r1mndwht
# INFO created /tmp/pyboolnet_fet9e_3y
# INFO created /tmp/pyboolnet_cbbpsoip
# INFO created /tmp/pyboolnet_5f2x6sb3
# INFO created /tmp/pyboolnet_me00gokv
# INFO created /tmp/pyboolnet_4cvholqv
# INFO created /tmp/pyboolnet_lrh54h6t
# INFO created /tmp/pyboolnet_s05mvgyf
# INFO created /tmp/pyboolnet_idjxzl5f
# INFO created /tmp/pyboolnet_0w_21svq
# INFO created /tmp/pyboolnet_qo324gnk
# INFO created /tmp/pyboolnet_td0euqep
# INFO created /tmp/pyboolnet_aavqt79l
# INFO created /tmp/pyboolnet_ux_y0efy
# INFO created /tmp/pyboolnet_naw0wsog
# INFO created /tmp/pyboolnet_i6dgfo2o
# INFO created /tmp/pyboolnet_xe2xe1t5
# INFO created /tmp/pyboolnet_r_1560iv
# INFO created /tmp/pyboolnet_w6z0_4u1
# INFO created /tmp/pyboolnet_pm3tgdd5
# INFO created /tmp/pyboolnet_9r65g99s
# INFO created /tmp/pyboolnet_m539t1he
# INFO created /tmp/pyboolnet_pt3y3s1o
# INFO created /tmp/pyboolnet_k2qnoutq
# INFO created /tmp/pyboolnet_lly81__d
# INFO created /tmp/pyboolnet_m3at2z55
# INFO created /tmp/pyboolnet_fa28d6gp
# INFO created /tmp/pyboolnet_gv332qyx
# INFO created /tmp/pyboolnet_5gn4owrr
# INFO created /tmp/pyboolnet_omnhu2j5
# INFO created /tmp/pyboolnet_rz3x2lvb
# INFO created /tmp/pyboolnet_9081ybsa
# INFO created /tmp/pyboolnet_vrefwgct
# INFO created /tmp/pyboolnet_33lryboa
# INFO created /tmp/pyboolnet_lgrymhvp
# INFO created /tmp/pyboolnet_hx5qe2yp
# INFO created /tmp/pyboolnet_t58malg9
# INFO created /tmp/pyboolnet_0q8ieobn
# INFO created /tmp/pyboolnet_u8kn6yk3
# INFO created /tmp/pyboolnet_5jgmwt38
# INFO created /tmp/pyboolnet_nopi0eho
# INFO created /tmp/pyboolnet_zwxdq0_z
# INFO created /tmp/pyboolnet_jq397gak
# INFO created /tmp/pyboolnet_0aza8m10
# INFO created /tmp/pyboolnet_qcpqikyl
# INFO created /tmp/pyboolnet_1hrqnhvx
# INFO created /tmp/pyboolnet_y1a_n22b
# INFO created /tmp/pyboolnet_o4jivj4a
# INFO created /tmp/pyboolnet_lb2flitk
# INFO created /tmp/pyboolnet_3qymytts
# INFO created /tmp/pyboolnet_jx67aya6
# INFO created /tmp/pyboolnet_9ff_dnco
# INFO created /tmp/pyboolnet_jlng75a4
# INFO created /tmp/pyboolnet_vy5v_uih
# INFO created /tmp/pyboolnet_c1o97vmh
# INFO created /tmp/pyboolnet__xgp_ee_
# INFO created /tmp/pyboolnet_eoj8gmcw
# INFO created /tmp/pyboolnet_xhuu1yck
# INFO created /tmp/pyboolnet__8fg_n9k
# INFO created /tmp/pyboolnet_weugk_co
# INFO created /tmp/pyboolnet_y87lp_46
# INFO created /tmp/pyboolnet_74rnkwnu
# INFO created /tmp/pyboolnet_u7sokc1t
# INFO created /tmp/pyboolnet_6bdbrfai
# INFO created /tmp/pyboolnet_bx3tslx6
# INFO created /tmp/pyboolnet_jk6f0t0q
# INFO created /tmp/pyboolnet_5mkq30p1
# INFO created /tmp/pyboolnet_ibsylz_s
# INFO created /tmp/pyboolnet_6hotbz0j
# INFO created /tmp/pyboolnet_16n2x6k9
# INFO created /tmp/pyboolnet_ukodpztp
# INFO created /tmp/pyboolnet_lhpndno8
# INFO created /tmp/pyboolnet_dcuupqzx
# INFO created /tmp/pyboolnet_540msv58
# INFO created /tmp/pyboolnet_cg506ki4
# INFO created /tmp/pyboolnet_ttzhyrq4
# INFO created /tmp/pyboolnet_kfx_86u8
# INFO created /tmp/pyboolnet_rx13dncl
# INFO created /tmp/pyboolnet_tkfposyq
# INFO created /tmp/pyboolnet_7ew0lq3f
# INFO created /tmp/pyboolnet_twynjve0
# INFO created /tmp/pyboolnet_w81qwhs_
# INFO created /tmp/pyboolnet_4p9yivas
# INFO created /tmp/pyboolnet__vobgib7
# INFO created /tmp/pyboolnet_2zackbo9
# INFO created /tmp/pyboolnet_o9euhfoc
# INFO created /tmp/pyboolnet_18s8clg_
# INFO created /tmp/pyboolnet_5qe_k3ln
# INFO created /tmp/pyboolnet_rcfjk1t3
# INFO created /tmp/pyboolnet_dbyfh5f8
# INFO created /tmp/pyboolnet_gltjs72d
# INFO created /tmp/pyboolnet_k55cy02u
# INFO created /tmp/pyboolnet_ksamop27
# INFO created /tmp/pyboolnet_s6i9dxb5
# INFO created /tmp/pyboolnet_mw0wdlia
# INFO created /tmp/pyboolnet_di8dcs1b
# INFO created /tmp/pyboolnet_fbe5binl
# INFO created /tmp/pyboolnet_d13b2fl7
# INFO created /tmp/pyboolnet_on16op2k
# INFO created /tmp/pyboolnet_1k3rmnrg
# INFO created /tmp/pyboolnet__7xo0epe
# INFO created /tmp/pyboolnet_zd3xr8vp
# INFO created /tmp/pyboolnet_ha6o7cvv
# INFO created /tmp/pyboolnet_i9ybvj9v
# INFO created /tmp/pyboolnet_a3hpey_e
# INFO created /tmp/pyboolnet_a9r249c_
# INFO created /tmp/pyboolnet_vdhyojk0
# INFO created /tmp/pyboolnet_7jn0vh5b
# INFO created /tmp/pyboolnet_bfxa7oac
# INFO created /tmp/pyboolnet_gbyf8cho
# INFO created /tmp/pyboolnet_8mfzfamo
# INFO created /tmp/pyboolnet_w0iwf30y
# INFO created /tmp/pyboolnet_q50mh1sr
# INFO created /tmp/pyboolnet_higzh_jp
# INFO created /tmp/pyboolnet_xtp2i84e
# INFO created /tmp/pyboolnet_w12m59lf
# INFO created /tmp/pyboolnet_m37vmms1
# INFO created /tmp/pyboolnet_jblemolv
# INFO created /tmp/pyboolnet_3qasko8c
# INFO created /tmp/pyboolnet_d73lkw66
# INFO created /tmp/pyboolnet_x56cx1cf
# INFO created /tmp/pyboolnet_blqppp_j
# INFO created /tmp/pyboolnet_cb61zqrl
# INFO created /tmp/pyboolnet_672bimkm
# INFO created /tmp/pyboolnet_rbkqlkzb
# INFO created /tmp/pyboolnet_nytg6s1v
# INFO created /tmp/pyboolnet__1qbwc49
# INFO created /tmp/pyboolnet_42vjqmzd
# INFO created /tmp/pyboolnet_ts30orqk
# INFO created /tmp/pyboolnet_br3a_rxz
# INFO created /tmp/pyboolnet_62vvzhus
# INFO created /tmp/pyboolnet_nl79ui11
# INFO created /tmp/pyboolnet_thi3ignt
# INFO created /tmp/pyboolnet_kh8ibda1
# INFO created /tmp/pyboolnet_pmlg54ka
# INFO created /tmp/pyboolnet_xp5c2a1c
# INFO created /tmp/pyboolnet_gto2fnyt
# INFO created /tmp/pyboolnet_f3kh51d_
# INFO created /tmp/pyboolnet_ja5x652s
# INFO created /tmp/pyboolnet_kkololxf
# INFO created /tmp/pyboolnet_funl3nx6
# INFO created /tmp/pyboolnet_dgwfkrzl
# INFO created /tmp/pyboolnet_0ng4o1hi
# INFO created /tmp/pyboolnet_y3tln7q0
# INFO created /tmp/pyboolnet_kiosbdom
# INFO created /tmp/pyboolnet_pojul5i3
# INFO created /tmp/pyboolnet_ffbt9ivl
# INFO created /tmp/pyboolnet_hz85oj_d
# INFO created /tmp/pyboolnet_0bjrrccx
# INFO created /tmp/pyboolnet_7d7h0pif
# INFO created /tmp/pyboolnet_7qq8sw1u
# INFO created /tmp/pyboolnet_oh72wxze
# INFO created /tmp/pyboolnet_x3mev1bu
# INFO created /tmp/pyboolnet_y44r9209
# INFO created /tmp/pyboolnet__r8hwpno
# INFO created /tmp/pyboolnet_vvy6xzsv
# INFO created /tmp/pyboolnet_jqd2du0k
# INFO created /tmp/pyboolnet_fgypgrnl
# INFO created /tmp/pyboolnet_2m__peyw
# INFO created /tmp/pyboolnet_w2gd7kp6
# INFO created /tmp/pyboolnet_yarkn3f3
# INFO created /tmp/pyboolnet_8up_zo00
# INFO created /tmp/pyboolnet_nmghqi8g
# INFO created /tmp/pyboolnet_6h6q9q4i
# INFO created /tmp/pyboolnet_vsm5suhv
# INFO created /tmp/pyboolnet_4gd_n049
# INFO created /tmp/pyboolnet_8_2htvc8
# INFO created /tmp/pyboolnet_tpy4dyhx
# INFO created /tmp/pyboolnet_2bssthdm
# INFO created /tmp/pyboolnet_3nnrtu75
# INFO created /tmp/pyboolnet_b_skl0hc
# INFO created /tmp/pyboolnet_codivhvg
# INFO created /tmp/pyboolnet_fcy5upfo
# INFO created /tmp/pyboolnet_ptotnnpn
# INFO created /tmp/pyboolnet_kvm66nhj
# INFO created /tmp/pyboolnet_ea8mnn7n
# INFO created /tmp/pyboolnet_81m_o77r
# INFO created /tmp/pyboolnet_e7kto8il
# INFO created /tmp/pyboolnet_ur81n9ou
# INFO created /tmp/pyboolnet_q_0kjsy5
# INFO created /tmp/pyboolnet_7zbqfmap
# INFO created /tmp/pyboolnet_hy75r_uu
# INFO created /tmp/pyboolnet_n7_mu9xw
# INFO created /tmp/pyboolnet_xmy35dxn
# INFO created /tmp/pyboolnet_6d06in4w
# INFO created /tmp/pyboolnet_6w12i85m
# INFO created /tmp/pyboolnet_1ekhujd5
# INFO created /tmp/pyboolnet_nw1d2f39
# INFO created /tmp/pyboolnet_7onbkiyi
# INFO created /tmp/pyboolnet_tr1cugzz
# INFO created /tmp/pyboolnet_7l__nj7n
# INFO created /tmp/pyboolnet_hsggsukd
# INFO created /tmp/pyboolnet_zbg9_fqq
# INFO created /tmp/pyboolnet_kjy0jo_3
# INFO created /tmp/pyboolnet_l6ivf0em
# INFO created /tmp/pyboolnet_7a2iwmw5
# INFO created /tmp/pyboolnet_02msmfni
# INFO created /tmp/pyboolnet_5p3ileyt
# INFO created /tmp/pyboolnet_k33mksmf
# INFO created /tmp/pyboolnet_1fb65gno
# INFO created /tmp/pyboolnet_2jyej6ie
# INFO created /tmp/pyboolnet_uyc_ozra
# INFO created /tmp/pyboolnet_29jnh3cj
# INFO created /tmp/pyboolnet_l3ojwof4
# INFO created /tmp/pyboolnet_ntequ0z6
# INFO created /tmp/pyboolnet_i5ukki0p
# INFO created /tmp/pyboolnet_a4vf9afi
# INFO created /tmp/pyboolnet_jtms5v1y
# INFO created /tmp/pyboolnet_qurqwolf
# INFO created /tmp/pyboolnet_b65l7j5d
# INFO created /tmp/pyboolnet_06__0g0s
# INFO created /tmp/pyboolnet_yg2e9e2k
# INFO created /tmp/pyboolnet_wtvq4maf
# INFO created /tmp/pyboolnet_xn53f3lj
# INFO created /tmp/pyboolnet_ynqnjva9
# INFO created /tmp/pyboolnet_p0nf2cfz
# INFO created /tmp/pyboolnet_x1p9eg2v
# INFO created /tmp/pyboolnet_arqsr10o
# INFO created /tmp/pyboolnet_0wq9q_bh
# INFO created /tmp/pyboolnet_gb2mhgo2
# INFO created /tmp/pyboolnet_5j48xef3
# INFO created /tmp/pyboolnet_birftdvy
# INFO created /tmp/pyboolnet_jm0pnx16
# INFO created /tmp/pyboolnet_ljy5w7ia
# INFO created /tmp/pyboolnet_uv1sthkf
# INFO created /tmp/pyboolnet_uqb6erd2
# INFO created /tmp/pyboolnet_ty5x5k6q
# INFO created /tmp/pyboolnet_nfif_cfe
# INFO created /tmp/pyboolnet_3r94gml5
# INFO created /tmp/pyboolnet_6nvgi1og
# INFO created /tmp/pyboolnet_r95ip7ks
# INFO created /tmp/pyboolnet_3arrmbl4
# INFO created /tmp/pyboolnet_0rsbmeb0
# INFO created /tmp/pyboolnet_c0irzwcx
# INFO created /tmp/pyboolnet_5j6a6r7c
# INFO created /tmp/pyboolnet_3x94493i
# INFO created /tmp/pyboolnet_y_d47bui
# INFO created /tmp/pyboolnet_0_g4r58d
# INFO created /tmp/pyboolnet_m_ytcqp1
# INFO created /tmp/pyboolnet_0lrhp11x
# INFO created /tmp/pyboolnet_ygpsoye7
# INFO created /tmp/pyboolnet_6fp3rt48
# INFO created /tmp/pyboolnet_gk02p8fm
# INFO created /tmp/pyboolnet_h10t3th0
# INFO created /tmp/pyboolnet_3q9vad5b
# INFO created /tmp/pyboolnet_x31u83ai
# INFO created /tmp/pyboolnet_9goax093
# INFO created /tmp/pyboolnet_1q_r2f31
# INFO created /tmp/pyboolnet_h43uxscz
# INFO created /tmp/pyboolnet_sucjgg38
# INFO created /tmp/pyboolnet_k_qgmhuv
# INFO created /tmp/pyboolnet_o0ys_tdv
# INFO created /tmp/pyboolnet_7_1feve5
# INFO created /tmp/pyboolnet_c3lixh15
# INFO created /tmp/pyboolnet_q_l4qfkc
# INFO created /tmp/pyboolnet_lt3sn2x3
# INFO created /tmp/pyboolnet_bxgztjc8
# INFO created /tmp/pyboolnet_qke95y3l
# INFO created /tmp/pyboolnet_evsk0jyw
# INFO created /tmp/pyboolnet_v7s5fws3
# INFO created /tmp/pyboolnet_7yrvy9u0
# INFO created /tmp/pyboolnet_lx3q36c3
# INFO created /tmp/pyboolnet_ulfw_zic
# INFO created /tmp/pyboolnet_d3ou3pzd
# INFO created /tmp/pyboolnet_i2zq9rlh
# INFO created /tmp/pyboolnet_0qa7tewm
# INFO created /tmp/pyboolnet_5galmnjt
# INFO created /tmp/pyboolnet_rsv7i4bj
# INFO created /tmp/pyboolnet_06arbtrn
# INFO created /tmp/pyboolnet_cph42tgw
# INFO created /tmp/pyboolnet_fmrcuwqs
# INFO created /tmp/pyboolnet_uelw03wd
# INFO created /tmp/pyboolnet__s39fo0r
# INFO created /tmp/pyboolnet_563wlgly
# INFO created /tmp/pyboolnet_glfwqkyc
# INFO created /tmp/pyboolnet_dpm3xr28
# INFO created /tmp/pyboolnet_gv_gdvdf
# INFO created /tmp/pyboolnet_7o5coqbb
# INFO created /tmp/pyboolnet_8rctctvt
# INFO created /tmp/pyboolnet_yh8ij2tf
# INFO created /tmp/pyboolnet_r_tjszxa
# INFO created /tmp/pyboolnet_1xkvbi85
# INFO created /tmp/pyboolnet_578bajfw
# INFO created /tmp/pyboolnet_2k5qxuy6
# INFO created /tmp/pyboolnet_m9bfedzl
# INFO created /tmp/pyboolnet_5nqeioo4
# INFO created /tmp/pyboolnet__12_stgn
# INFO created /tmp/pyboolnet_07xhyw7_
# INFO created /tmp/pyboolnet_dydyre5i
# INFO created /tmp/pyboolnet_xj37g_vk
# INFO created /tmp/pyboolnet_4bnz9v09
# INFO created /tmp/pyboolnet_n2ivbop6
# INFO created /tmp/pyboolnet_li1udmhv
# INFO created /tmp/pyboolnet_28se5w5z
# INFO created /tmp/pyboolnet_f1h73fj0
# INFO created /tmp/pyboolnet_ybl_7mg1
# INFO created /tmp/pyboolnet_gigh35ut
# INFO created /tmp/pyboolnet_836u9tih
# INFO created /tmp/pyboolnet_n7_pwgtf
# INFO created /tmp/pyboolnet_lhfryb15
# INFO created /tmp/pyboolnet_mpq8o1qc
# INFO created /tmp/pyboolnet_icvtjelc
# INFO created /tmp/pyboolnet__0vo98nm
# INFO created /tmp/pyboolnet_y8piyf0e
# INFO created /tmp/pyboolnet_vaigzft1
# INFO created /tmp/pyboolnet_nh5rzy9b
# INFO created /tmp/pyboolnet_rw0g8ik6
# INFO created /tmp/pyboolnet_o0v23tsl
# INFO created /tmp/pyboolnet_67yxf4f5
# INFO created /tmp/pyboolnet_mqbcud3i
# INFO created /tmp/pyboolnet_cvmd7xx7
# INFO created /tmp/pyboolnet_1yojhbop
# INFO created /tmp/pyboolnet_bjd4l_h2
# INFO created /tmp/pyboolnet_fuswx_jx
# INFO created /tmp/pyboolnet_yyqr15qs
# INFO created /tmp/pyboolnet_2nnva1q0
# INFO created /tmp/pyboolnet_zxo342vx
# INFO created /tmp/pyboolnet_257pv8ud
# INFO created /tmp/pyboolnet_4uofuxto
# INFO created /tmp/pyboolnet_rhw_jbiq
# INFO created /tmp/pyboolnet_adctvwpt
# INFO created /tmp/pyboolnet_mc19fp_f
# INFO created /tmp/pyboolnet_hwzw57c_
# INFO created /tmp/pyboolnet_cwqj5y3k
# INFO created /tmp/pyboolnet_p7i4qhu4
# INFO created /tmp/pyboolnet_3bdo22cw
# INFO created /tmp/pyboolnet_q7wivx31
# INFO created /tmp/pyboolnet_ivy3w5cv
# INFO created /tmp/pyboolnet_g8ggncd_
# INFO created /tmp/pyboolnet_rdrytdb0
# INFO created /tmp/pyboolnet_9aqsju7z
# INFO created /tmp/pyboolnet_e3o91omz
# INFO created /tmp/pyboolnet_no2o1oug
# INFO created /tmp/pyboolnet_dy77xvql
# INFO created /tmp/pyboolnet_d6gyyxlw
# INFO created /tmp/pyboolnet_mpue5ohz
# INFO created /tmp/pyboolnet_c4m8vfbd
# INFO created /tmp/pyboolnet_jjbgu7ke
# INFO created /tmp/pyboolnet_lad2p4r0
# INFO created /tmp/pyboolnet_vtqdkv76
# INFO created /tmp/pyboolnet_id0itx41
# INFO created /tmp/pyboolnet_8eomjo80
# INFO created /tmp/pyboolnet_17x3w2hg
# INFO created /tmp/pyboolnet__wmcxbr7
# INFO created /tmp/pyboolnet_w5j9v7he
# INFO created /tmp/pyboolnet_ifrka8pj
# INFO created /tmp/pyboolnet_bcolv13q
# INFO created /tmp/pyboolnet_47g4oc51
# INFO created /tmp/pyboolnet__5ju1khb
# INFO created /tmp/pyboolnet_j8g_8277
# INFO created /tmp/pyboolnet_6l28v9qm
# INFO created /tmp/pyboolnet_ij4c5z35
# INFO created /tmp/pyboolnet_q1_lkp8t
# INFO created /tmp/pyboolnet_pf_sdjc3
# INFO created /tmp/pyboolnet_pbxiwre9
# INFO created /tmp/pyboolnet_r3ydpawc
# INFO created /tmp/pyboolnet_emvphvcz
# INFO created /tmp/pyboolnet_x4m227uv
# INFO created /tmp/pyboolnet_x3chcznx
# INFO created /tmp/pyboolnet_px2ysh6g
# INFO created /tmp/pyboolnet_f7r6d4ir
# INFO created /tmp/pyboolnet_0bwf3wct
# INFO created /tmp/pyboolnet_qcehl4sm
# INFO created /tmp/pyboolnet_t1ptzb97
# INFO created /tmp/pyboolnet_dqowt9wg
# INFO created /tmp/pyboolnet_pnl26pb2
# INFO created /tmp/pyboolnet_rbrq24s0
# INFO created /tmp/pyboolnet_i9zaj3jf
# INFO created /tmp/pyboolnet_xd7jryly
# INFO created /tmp/pyboolnet_ylb_2879
# INFO created /tmp/pyboolnet_v37ncwhj
# INFO created /tmp/pyboolnet_gzzprwrk
# INFO created /tmp/pyboolnet_x90cyrif
# INFO created /tmp/pyboolnet_y7h3i40p
# INFO created /tmp/pyboolnet_sfcc6ghf
# INFO created /tmp/pyboolnet_0ny4npjn
# INFO created /tmp/pyboolnet_rbfzfqah
# INFO created /tmp/pyboolnet_m1km79uq
# INFO created /tmp/pyboolnet_1fmycn0a
# INFO created /tmp/pyboolnet_c533y6k7
# INFO created /tmp/pyboolnet_y8wdp_g9
# INFO created /tmp/pyboolnet_z9s0sr8a
# INFO created /tmp/pyboolnet_9fn_g1uy
# INFO created /tmp/pyboolnet_qt0pcpgv
# INFO created /tmp/pyboolnet_7jc9ctje
# INFO created /tmp/pyboolnet_7wsmbgx8
# INFO created /tmp/pyboolnet_h8g02nqz
# INFO created /tmp/pyboolnet_9an5ajqt
# INFO created /tmp/pyboolnet_mj95_rqm
# INFO created /tmp/pyboolnet_j2yv1_p_
# INFO created /tmp/pyboolnet_ht68l6n0
# INFO created /tmp/pyboolnet_hmwifwog
# INFO created /tmp/pyboolnet_9omm6g_m
# INFO created /tmp/pyboolnet_1v2hho6g
# INFO created /tmp/pyboolnet_4ilmd6oh
# INFO created /tmp/pyboolnet_o6gbl3hq
# INFO created /tmp/pyboolnet_ibb_x55t
# INFO created /tmp/pyboolnet_3dp_v5ff
# INFO created /tmp/pyboolnet_df13gtnt
# INFO created /tmp/pyboolnet_dhbnxzlc
# INFO created /tmp/pyboolnet_8knz7ivw
# INFO created /tmp/pyboolnet_b464ej4y
# INFO created /tmp/pyboolnet_tarisl3p
# INFO created /tmp/pyboolnet_e6w_4pwt
# INFO created /tmp/pyboolnet_xy2_w2uc
# INFO created /tmp/pyboolnet_mcf7pddk
# INFO created /tmp/pyboolnet_ke4m76xi
# INFO created /tmp/pyboolnet_fqzwnewn
# INFO created /tmp/pyboolnet_7o1i824e
# INFO created /tmp/pyboolnet_n9fj7hzh
# INFO created /tmp/pyboolnet_s2oaa0c1
# INFO created /tmp/pyboolnet_cwd4buy_
# INFO created /tmp/pyboolnet_zw219qxu
# INFO created /tmp/pyboolnet_jpxkmnj7
# INFO created /tmp/pyboolnet_fapk8w6z
# INFO created /tmp/pyboolnet_8zufu404
# INFO created /tmp/pyboolnet_chwpzlzp
# INFO created /tmp/pyboolnet_pz3wmsfj
# INFO created /tmp/pyboolnet_i6e3o86_
# INFO created /tmp/pyboolnet_pv47o849
# INFO created /tmp/pyboolnet_2cjwwhbs
# INFO created /tmp/pyboolnet_u156jmvi
# INFO created /tmp/pyboolnet__yj9ro94
# INFO created /tmp/pyboolnet_xgjk0z51
# INFO created /tmp/pyboolnet_3wflz17u
# INFO created /tmp/pyboolnet_lm8mpst_
# INFO created /tmp/pyboolnet_ql55utg_
# INFO created /tmp/pyboolnet_gmyg_uth
# INFO created /tmp/pyboolnet_ezoj0d25
# INFO created /tmp/pyboolnet_01jcjcmy
# INFO created /tmp/pyboolnet_pp28q_jl
# INFO created /tmp/pyboolnet_zaoi99mj
# INFO created /tmp/pyboolnet_tr6xyd4i
# INFO created /tmp/pyboolnet_pmpa021h
# INFO created /tmp/pyboolnet_6jlh1v1d
# INFO created /tmp/pyboolnet_bkguj6wa
# INFO created /tmp/pyboolnet_733g4_rx
# INFO created /tmp/pyboolnet_pne1dpqa
# INFO created /tmp/pyboolnet_vjtni94x
# INFO created /tmp/pyboolnet_9jpde3yv
# INFO created /tmp/pyboolnet_5yeojt8f
# INFO created /tmp/pyboolnet_2_brx_me
# INFO created /tmp/pyboolnet_7aws599g
# INFO created /tmp/pyboolnet_q7xclpid
# INFO created /tmp/pyboolnet_48g5b3s5
# INFO created /tmp/pyboolnet__e1ygfch
# INFO created /tmp/pyboolnet_i9kamw60
# INFO created /tmp/pyboolnet_okg83w1n
# INFO created /tmp/pyboolnet_4y97r9l9
# INFO created /tmp/pyboolnet_clqacz7y
# INFO created /tmp/pyboolnet_rpe4b5tf
# INFO created /tmp/pyboolnet_lgk9a3pf
# INFO created /tmp/pyboolnet_ul91hlwh
# INFO created /tmp/pyboolnet_7_q0h4ni
# INFO created /tmp/pyboolnet_ampb08b5
# INFO created /tmp/pyboolnet_lzhvlwk4
# INFO created /tmp/pyboolnet_vmpjepyr
# INFO created /tmp/pyboolnet_jl6j28mt
# INFO created /tmp/pyboolnet_ek0716jw
# INFO created /tmp/pyboolnet_rwuugr6y
# INFO created /tmp/pyboolnet_dquvkmtu
# INFO created /tmp/pyboolnet_3a01t0zi
# INFO created /tmp/pyboolnet_lzog5xrw
# INFO created /tmp/pyboolnet_2up4_8s1
# INFO created /tmp/pyboolnet_ftz4ca85
# INFO created /tmp/pyboolnet_1gdw8fen
# INFO created /tmp/pyboolnet_ohb9_r5x
# INFO created /tmp/pyboolnet_h468jk10
# INFO created /tmp/pyboolnet_p9ph72l4
# INFO created /tmp/pyboolnet_kvfhivni
# INFO created /tmp/pyboolnet_iyd75e91
# INFO created /tmp/pyboolnet_565ll86r
# INFO created /tmp/pyboolnet_npc4dxt7
# INFO created /tmp/pyboolnet_fvum76mm
# INFO created /tmp/pyboolnet_87ddmc8l
# INFO created /tmp/pyboolnet_2j0p6ojq
# INFO created /tmp/pyboolnet_z7xt7mnn
# INFO created /tmp/pyboolnet_v2bsn2_4
# INFO created /tmp/pyboolnet_cp467jo4
# INFO created /tmp/pyboolnet_q1ads37w
# INFO created /tmp/pyboolnet_xyt210aq
# INFO created /tmp/pyboolnet_4sd3ojr2
# INFO created /tmp/pyboolnet_n_en4nn2
# INFO created /tmp/pyboolnet__u8uf85p
# INFO created /tmp/pyboolnet_yhtxtdw9
# INFO created /tmp/pyboolnet_qmrasrum
# INFO created /tmp/pyboolnet_7nfv2kvp
# INFO created /tmp/pyboolnet_1r2j7cj3
# INFO created /tmp/pyboolnet_5d9k82gz
# INFO created /tmp/pyboolnet_5hgd3da9
# INFO created /tmp/pyboolnet_eagsxdhs
# INFO created /tmp/pyboolnet_8to0g1v5
# INFO created /tmp/pyboolnet_25ewe2vu
# INFO created /tmp/pyboolnet_gecq7p3d
# INFO created /tmp/pyboolnet_4hg_5qy5
# INFO created /tmp/pyboolnet_nwl_85we
# INFO created /tmp/pyboolnet_2qu6t2ql
# INFO created /tmp/pyboolnet_1dkzycb6
# INFO created /tmp/pyboolnet_f6xqywp0
# INFO created /tmp/pyboolnet_91b4tjwp
# INFO created /tmp/pyboolnet_ysa1n1b0
# INFO created /tmp/pyboolnet_n0j13rvu
# INFO created /tmp/pyboolnet_7qabaey_
# INFO created /tmp/pyboolnet_7tftlras
# INFO created /tmp/pyboolnet_mx3cz5o8
# INFO created /tmp/pyboolnet_wh3fwnuo
# INFO created /tmp/pyboolnet_ncicejsv
# INFO created /tmp/pyboolnet_ug6f_4sj
# INFO created /tmp/pyboolnet_9es9bjmm
# INFO created /tmp/pyboolnet_eq4g91po
# INFO created /tmp/pyboolnet_ir1nzo8l
# INFO created /tmp/pyboolnet_zwyd6tsv
# INFO created /tmp/pyboolnet_0cbit5c7
# INFO created /tmp/pyboolnet_5315h_46
# INFO created /tmp/pyboolnet_7l9zca2d
# INFO created /tmp/pyboolnet_ufx523u_
# INFO created /tmp/pyboolnet_gkyts_8m
# INFO created /tmp/pyboolnet_7jo7gs48
# INFO created /tmp/pyboolnet_mpme8kit
# INFO created /tmp/pyboolnet_kypgcurm
# INFO created /tmp/pyboolnet_5s4b9afu
# INFO created /tmp/pyboolnet_8wba1h_n
# INFO created /tmp/pyboolnet_oo_9zb82
# INFO created /tmp/pyboolnet_8h8qu8wc
# INFO created /tmp/pyboolnet_ya2wr354
# INFO created /tmp/pyboolnet_4gxw_cgu
# INFO created /tmp/pyboolnet_8g4unelo
# INFO created /tmp/pyboolnet_v6e66_yd
# INFO created /tmp/pyboolnet_sg9_9z4f
# INFO created /tmp/pyboolnet_kyvqc54v
# INFO created /tmp/pyboolnet_7tukc_4y
# INFO created /tmp/pyboolnet_bgpe1qpy
# INFO created /tmp/pyboolnet_1x_nicpv
# INFO created /tmp/pyboolnet_8gx4keyc
# INFO created /tmp/pyboolnet_si_89h2_
# INFO created /tmp/pyboolnet_no_avtwm
# INFO created /tmp/pyboolnet_autw68so
# INFO created /tmp/pyboolnet_ka_4djuv
# INFO created /tmp/pyboolnet_pxdjz9vz
# INFO created /tmp/pyboolnet_gkwq8wj2
# INFO created /tmp/pyboolnet_5e557s5a
# INFO created /tmp/pyboolnet_gndz3ykp
# INFO created /tmp/pyboolnet_xakj10we
# INFO created /tmp/pyboolnet_e_mvw9es
# INFO created /tmp/pyboolnet_lpm24lbi
# INFO created /tmp/pyboolnet_na6ku5ro
# INFO created /tmp/pyboolnet_5jiunfsf
# INFO created /tmp/pyboolnet_39cw1gr_
# INFO created /tmp/pyboolnet_g5xqxcdr
# INFO created /tmp/pyboolnet_1tbwv8tw
# INFO created /tmp/pyboolnet_78xchtbm
# INFO created /tmp/pyboolnet_tks_35lp
# INFO created /tmp/pyboolnet_zltr4mp1
# INFO created /tmp/pyboolnet_n49zy9s_
# INFO created /tmp/pyboolnet_dwdesk6i
# INFO created /tmp/pyboolnet_nuaelii9
# INFO created /tmp/pyboolnet_63xv0f2d
# INFO created /tmp/pyboolnet_6zr_pxf2
# INFO created /tmp/pyboolnet_r80_kjdc
# INFO created /tmp/pyboolnet_h3_37709
# INFO created /tmp/pyboolnet_s95eotma
# INFO created /tmp/pyboolnet_3_ss11hg
# INFO created /tmp/pyboolnet_dav95fhb
# INFO created /tmp/pyboolnet_nun3q46v
# INFO created /tmp/pyboolnet_ke8i_qxn
# INFO created /tmp/pyboolnet_t7anr_zi
# INFO created /tmp/pyboolnet_8n53rn3f
# INFO created /tmp/pyboolnet_sx_also4
# INFO created /tmp/pyboolnet_txe8_nv0
# INFO created /tmp/pyboolnet_a45jgjw4
# INFO created /tmp/pyboolnet_slmcu4b1
# INFO created /tmp/pyboolnet_4lz9jlji
# INFO created /tmp/pyboolnet_7hyv73t0
# INFO created /tmp/pyboolnet_nbjlgbd0
# INFO created /tmp/pyboolnet_f8ufpdsj
# INFO created /tmp/pyboolnet_6vs3jnxf
# INFO created /tmp/pyboolnet_cbg29t60
# INFO created /tmp/pyboolnet_xjtxbiwl
# INFO created /tmp/pyboolnet_kvwfk3ur
# INFO created /tmp/pyboolnet_bo4ohf5x
# INFO created /tmp/pyboolnet_od9z83e0
# INFO created /tmp/pyboolnet_i9l84uc9
# INFO created /tmp/pyboolnet_iwa370fa
# INFO created /tmp/pyboolnet_v05rnnn2
# INFO created /tmp/pyboolnet_zg75bdst
# INFO created /tmp/pyboolnet_3qqoep5e
# INFO created /tmp/pyboolnet_zztkrvgr
# INFO created /tmp/pyboolnet_5ax7rgh0
# INFO created /tmp/pyboolnet_vryudy4m
# INFO created /tmp/pyboolnet_1vrtt_dk
# INFO created /tmp/pyboolnet_d3cyp7zv
# INFO created /tmp/pyboolnet_1p4s87wp
# INFO created /tmp/pyboolnet_nqnasvxy
# INFO created /tmp/pyboolnet_chusds7f
# INFO created /tmp/pyboolnet_k0_yjd3i
# INFO created /tmp/pyboolnet_b4mbxekf
# INFO created /tmp/pyboolnet_xhd85ot7
# INFO created /tmp/pyboolnet_9gzu7pnu
# INFO created /tmp/pyboolnet_647p_3w5
# INFO created /tmp/pyboolnet_26ke2t0l
# INFO created /tmp/pyboolnet_wvmq5hc6
# INFO created /tmp/pyboolnet_zyaa_w26
# INFO created /tmp/pyboolnet_cbs_udfx
# INFO created /tmp/pyboolnet_cxisf339
# INFO created /tmp/pyboolnet_b8dc5wuf
# INFO created /tmp/pyboolnet_r4hr9pao
# INFO created /tmp/pyboolnet_fxdpl29k
# INFO created /tmp/pyboolnet_if8ah1tz
# INFO created /tmp/pyboolnet_t_c9k98h
# INFO created /tmp/pyboolnet_vkznl36y
# INFO created /tmp/pyboolnet_u606jcgc
# INFO created /tmp/pyboolnet_ovjhg4yj
# INFO created /tmp/pyboolnet_xrleatvn
# INFO created /tmp/pyboolnet_lfo2t_vt
# INFO created /tmp/pyboolnet_fp2ulhdn
# INFO created /tmp/pyboolnet_ob8g0hxp
# INFO created /tmp/pyboolnet_kvq28q9e
# INFO created /tmp/pyboolnet_43bzz4ja
# INFO created /tmp/pyboolnet_bra2dgup
# INFO created /tmp/pyboolnet_1ooaxjfo
# INFO created /tmp/pyboolnet_so6uqts5
# INFO created /tmp/pyboolnet_ghddinug
# INFO created /tmp/pyboolnet_5yy3dqss
# INFO created /tmp/pyboolnet__8cmgfkh
# INFO created /tmp/pyboolnet_0zzcrosc
# INFO created /tmp/pyboolnet_1289mq5z
# INFO created /tmp/pyboolnet_pqfv3ftj
# INFO created /tmp/pyboolnet_pl_6ztua
# INFO created /tmp/pyboolnet_ausphi1t
# INFO created /tmp/pyboolnet__xvepxib
# INFO created /tmp/pyboolnet_ca23s64n
# INFO created /tmp/pyboolnet_ysdf072d
# INFO created /tmp/pyboolnet_kjlvl837
# INFO created /tmp/pyboolnet_zo0nv4be
# INFO created /tmp/pyboolnet_5jzx4u2_
# INFO created /tmp/pyboolnet_tskb5wgl
# INFO created /tmp/pyboolnet_sjw4r7no
# INFO created /tmp/pyboolnet_x4n4zffm
# INFO created /tmp/pyboolnet_k2432net
# INFO created /tmp/pyboolnet_ei4tlo13
# INFO created /tmp/pyboolnet_zy5ywpb3
# INFO created /tmp/pyboolnet_299vtul8
# INFO created /tmp/pyboolnet_34bgke4b
# INFO created /tmp/pyboolnet_ffncq27i
# INFO created /tmp/pyboolnet__jukq4pm
# INFO created /tmp/pyboolnet_01975_bv
# INFO created /tmp/pyboolnet_6evq9uqh
# INFO created /tmp/pyboolnet_sjn36vx7
# INFO created /tmp/pyboolnet_gwpqzy_o
# INFO created /tmp/pyboolnet_v4ttbvis
# INFO created /tmp/pyboolnet_af9wp507
# INFO created /tmp/pyboolnet_o094_gyp
# INFO created /tmp/pyboolnet_kzg7l7fe
# INFO created /tmp/pyboolnet_mc6t720s
# INFO created /tmp/pyboolnet_o_22v3j4
# INFO created /tmp/pyboolnet_fjfwvpp8
# INFO created /tmp/pyboolnet_9syxzfdx
# INFO created /tmp/pyboolnet_be21rgmg
# INFO created /tmp/pyboolnet_7ayfkc9m
# INFO created /tmp/pyboolnet_u66_vnis
# INFO created /tmp/pyboolnet_l291i7eg
# INFO created /tmp/pyboolnet_pc0ydqxg
# INFO created /tmp/pyboolnet_a6p5onqk
# INFO created /tmp/pyboolnet_8ywnkoes
# INFO created /tmp/pyboolnet_oe91yci1
# INFO created /tmp/pyboolnet_tdzfgjdq
# INFO created /tmp/pyboolnet_bntqfon8
# INFO created /tmp/pyboolnet_k7f480oc
# INFO created /tmp/pyboolnet_n_i6oigh
# INFO created /tmp/pyboolnet_2u5l__73
# INFO created /tmp/pyboolnet_0xygtpux
# INFO created /tmp/pyboolnet_edzz4am9
# INFO created /tmp/pyboolnet_1l2lmu6g
# INFO created /tmp/pyboolnet_123g19j9
# INFO created /tmp/pyboolnet_87npbhg5
# INFO created /tmp/pyboolnet_i6bq4_td
# INFO created /tmp/pyboolnet_i3pt00rb
# INFO created /tmp/pyboolnet_8vacrv1t
# INFO created /tmp/pyboolnet_owni6svk
# INFO created /tmp/pyboolnet_xshbsvh5
# INFO created /tmp/pyboolnet_brj7lyyk
# INFO created /tmp/pyboolnet_4pvp2rjk
# INFO created /tmp/pyboolnet_cilc55do
# INFO created /tmp/pyboolnet_13m2gu63
# INFO created /tmp/pyboolnet_cd7gpi91
# INFO created /tmp/pyboolnet_ms1bzr79
# INFO created /tmp/pyboolnet_z0r9dnlh
# INFO created /tmp/pyboolnet_nvglfdz9
# INFO created /tmp/pyboolnet_p6nhs_o_
# INFO created /tmp/pyboolnet_gmjqc3n1
# INFO created /tmp/pyboolnet_3ihs__es
# INFO created /tmp/pyboolnet_whb7v1ck
# INFO created /tmp/pyboolnet_7a3c2pqd
# INFO created /tmp/pyboolnet_uzk963vq
# INFO created /tmp/pyboolnet_bd4hasiz
# INFO created /tmp/pyboolnet_ohjj99mv
# INFO created /tmp/pyboolnet_vpw_mx7e
# INFO created /tmp/pyboolnet_6sw2n3vv
# INFO created /tmp/pyboolnet_nb945jb_
# INFO created /tmp/pyboolnet_inao_yxw
# INFO created /tmp/pyboolnet__n55icso
# INFO created /tmp/pyboolnet_ddhq4gdb
# INFO created /tmp/pyboolnet_ihv7897e
# INFO created /tmp/pyboolnet_iawhbgh2
# INFO created /tmp/pyboolnet_0p7lcp6k
# INFO created /tmp/pyboolnet_8w1fvya9
# INFO created /tmp/pyboolnet_kjy4oy5i
# INFO created /tmp/pyboolnet_6ut00kf1
# INFO created /tmp/pyboolnet_kadswdsc
# INFO created /tmp/pyboolnet_3lx3fbog
# INFO created /tmp/pyboolnet_hgc33oi0
# INFO created /tmp/pyboolnet_akp9qne5
# INFO created /tmp/pyboolnet_dr8b2fhf
# INFO created /tmp/pyboolnet_bp93eoiy
# INFO created /tmp/pyboolnet_f_n449s2
# INFO created /tmp/pyboolnet_r7qbbw4l
# INFO created /tmp/pyboolnet_5u48hnrg
# INFO created /tmp/pyboolnet_g1uw5dt1
# INFO created /tmp/pyboolnet_o92kammt
# INFO created /tmp/pyboolnet_2u8z72f7
# INFO created /tmp/pyboolnet_inw7nljv
# INFO created /tmp/pyboolnet_3w4bb0sx
# INFO created /tmp/pyboolnet_gqsycr00
# INFO created /tmp/pyboolnet__xi1xyrw
# INFO created /tmp/pyboolnet_kjzvaktd
# INFO created /tmp/pyboolnet_i8w2huj6
# INFO created /tmp/pyboolnet_0wqhjsta
# INFO created /tmp/pyboolnet_qb8ah2xc
# INFO created /tmp/pyboolnet_fes52odt
# INFO created /tmp/pyboolnet_vbrwvcxy
# INFO created /tmp/pyboolnet_orq6o9mp
# INFO created /tmp/pyboolnet_yktsilrn
# INFO created /tmp/pyboolnet_fyldtglu
# INFO created /tmp/pyboolnet_72lg_hl2
# INFO created /tmp/pyboolnet_wpawg5zc
# INFO created /tmp/pyboolnet_vipmwndw
# INFO created /tmp/pyboolnet_du05t5hd
# INFO created /tmp/pyboolnet_k52o7x6a
# INFO created /tmp/pyboolnet_vawuoff_
# INFO created /tmp/pyboolnet_wp3iag_y
# INFO created /tmp/pyboolnet_ih5mxcyi
# INFO created /tmp/pyboolnet_m0d695l2
# INFO created /tmp/pyboolnet_enpmsg7p
# INFO created /tmp/pyboolnet_pl63r3ko
# INFO created /tmp/pyboolnet_gty2ipwf
# INFO created /tmp/pyboolnet_j56psdeu
# INFO created /tmp/pyboolnet_o36sek46
# INFO created /tmp/pyboolnet_if7cyqhy
# INFO created /tmp/pyboolnet_bp7jd8dn
# INFO created /tmp/pyboolnet_1m0kzauj
# INFO created /tmp/pyboolnet_znjbz78b
# INFO created /tmp/pyboolnet_0f5sozq_
# INFO created /tmp/pyboolnet_689p3ps6
# INFO created /tmp/pyboolnet_off3lyqk
# INFO created /tmp/pyboolnet_su64gbvj
# INFO created /tmp/pyboolnet_n1u350q7
# INFO created /tmp/pyboolnet_x5ygyy6b
# INFO created /tmp/pyboolnet_s3ua2yhe
# INFO created /tmp/pyboolnet_bjspt3ye
# INFO created /tmp/pyboolnet_gcv2qkfc
# INFO created /tmp/pyboolnet_ba8c22fx
# INFO created /tmp/pyboolnet_8m1gjnim
# INFO created /tmp/pyboolnet_49a8sghx
# INFO created /tmp/pyboolnet_rg2h4tqt
# INFO created /tmp/pyboolnet_lglue4j8
# INFO created /tmp/pyboolnet_f8v1o653
# INFO created /tmp/pyboolnet_19s_tz9h
# INFO created /tmp/pyboolnet_yazk7vgk
# INFO created /tmp/pyboolnet_3z0l8vu2
# INFO created /tmp/pyboolnet_slq4pgrk
# INFO created /tmp/pyboolnet_xej280ev
# INFO created /tmp/pyboolnet_mvs_b5vd
# INFO created /tmp/pyboolnet_p8nogs7m
# INFO created /tmp/pyboolnet_hh65rqri
# INFO created /tmp/pyboolnet_6wx5ola3
# INFO created /tmp/pyboolnet_hgz402br
# INFO created /tmp/pyboolnet_03tlynzb
# INFO created /tmp/pyboolnet_lox4kll0
# INFO created /tmp/pyboolnet_qpoia0jx
# INFO created /tmp/pyboolnet_dzgsks44
# INFO created /tmp/pyboolnet_jpdw54yn
# INFO created /tmp/pyboolnet_cr3zg5ea
# INFO created /tmp/pyboolnet_cm9t6bjj
# INFO created /tmp/pyboolnet_no_o32p1
# INFO created /tmp/pyboolnet_fpo_zmov
# INFO created /tmp/pyboolnet_ugpe21hm
# INFO created /tmp/pyboolnet_dbm6g91a
# INFO created /tmp/pyboolnet_wj_gbo2m
# INFO created /tmp/pyboolnet_zfzo77yw
# INFO created /tmp/pyboolnet_tnu0ubgn
# INFO created /tmp/pyboolnet_802m36t1
# INFO created /tmp/pyboolnet_t7bbmr02
# INFO created /tmp/pyboolnet_9yt5k9i1
# INFO created /tmp/pyboolnet_xi0c6emn
# INFO created /tmp/pyboolnet_g_3x2thv
# INFO created /tmp/pyboolnet_trub3_tg
# INFO created /tmp/pyboolnet_6puplxqf
# INFO created /tmp/pyboolnet_ebe1gnva
# INFO created /tmp/pyboolnet_fdr9rl0z
# INFO created /tmp/pyboolnet_a1xu9f4_
# INFO created /tmp/pyboolnet_g67u77v_
# INFO created /tmp/pyboolnet_67mayaka
# INFO created /tmp/pyboolnet_b5_lsgl7
# INFO created /tmp/pyboolnet_ael1sxse
# INFO created /tmp/pyboolnet_wrewbrbe
# INFO created /tmp/pyboolnet_f2f7_51u
# INFO created /tmp/pyboolnet_0d2zpptx
# INFO created /tmp/pyboolnet_t7q3i9gb
# INFO created /tmp/pyboolnet_lrwtaw0h
# INFO created /tmp/pyboolnet_zflor5fk
# INFO created /tmp/pyboolnet_wec7dlxe
# INFO created /tmp/pyboolnet_uzhhhx53
# INFO created /tmp/pyboolnet__eydtbk2
# INFO created /tmp/pyboolnet_ztsyn_e4
# INFO created /tmp/pyboolnet_4bbaxwfb
# INFO created /tmp/pyboolnet_uxys7myr
# INFO created /tmp/pyboolnet_d47j7z4q
# INFO created /tmp/pyboolnet_96qmysm3
# INFO created /tmp/pyboolnet_6evxjdh3
# INFO created /tmp/pyboolnet_2_6fosmr
# INFO created /tmp/pyboolnet_1jvu1ez6
# INFO created /tmp/pyboolnet_6z4cp2um
# INFO created /tmp/pyboolnet_yrqoz149
# INFO created /tmp/pyboolnet_xk9ic_v1
# INFO created /tmp/pyboolnet_x8t3r1o5
# INFO created /tmp/pyboolnet_kzag2llb
# INFO created /tmp/pyboolnet_1xpm2q1r
# INFO created /tmp/pyboolnet_kzcpeb8b
# INFO created /tmp/pyboolnet_qj3u5gww
# INFO created /tmp/pyboolnet_5dwb8q5x
# INFO created /tmp/pyboolnet_lrgc845n
# INFO created /tmp/pyboolnet_h_7hzvjz
# INFO created /tmp/pyboolnet_yl2ue7uk
# INFO created /tmp/pyboolnet_avbt1zb9
# INFO created /tmp/pyboolnet_tmdhh2d9
# INFO created /tmp/pyboolnet_cityn28u
# INFO created /tmp/pyboolnet_rbn6guil
# INFO created /tmp/pyboolnet_3k01mesm
# INFO created /tmp/pyboolnet_46nn4tf1
# INFO created /tmp/pyboolnet_7az66zh4
# INFO created /tmp/pyboolnet_x10lxi39
# INFO created /tmp/pyboolnet_gzzlbvm3
# INFO created /tmp/pyboolnet_lvdbppg5
# INFO created /tmp/pyboolnet_fbazmdtj
# INFO created /tmp/pyboolnet_0gnu2bfg
# INFO created /tmp/pyboolnet_36nwehe4
# INFO created /tmp/pyboolnet_fzn5tby0
# INFO created /tmp/pyboolnet_fioj3jn1
# INFO created /tmp/pyboolnet_tzxe_4is
# INFO created /tmp/pyboolnet_pmfcgdab
# INFO created /tmp/pyboolnet_8l36q7nv
# INFO created /tmp/pyboolnet_oox22z4w
# INFO created /tmp/pyboolnet_880goedo
# INFO created /tmp/pyboolnet_vpl95bqz
# INFO created /tmp/pyboolnet_joxf_bur
# INFO created /tmp/pyboolnet_js8l09nr
# INFO created /tmp/pyboolnet_lvp381fe
# INFO created /tmp/pyboolnet_gdor9vtt
# INFO created /tmp/pyboolnet_j3l6y9cm
# INFO created /tmp/pyboolnet_v_it3jpf
# INFO created /tmp/pyboolnet_bvzm0fla
# INFO created /tmp/pyboolnet_h84ye9z4
# INFO created /tmp/pyboolnet_6tsskspl
# INFO created /tmp/pyboolnet_br6r_ij6
# INFO created /tmp/pyboolnet_wwj93yhv
# INFO created /tmp/pyboolnet_6lzazkdo
# INFO created /tmp/pyboolnet_fcgipqm1
# INFO created /tmp/pyboolnet_v67ndbf6
# INFO created /tmp/pyboolnet_jrqiv4ir
# INFO created /tmp/pyboolnet_h419m0om
# INFO created /tmp/pyboolnet_x39kg1ii
# INFO created /tmp/pyboolnet_dgf_qop1
# INFO created /tmp/pyboolnet_h9kn9g22
# INFO created /tmp/pyboolnet_8e6gdycz
# INFO created /tmp/pyboolnet_pwac31u1
# INFO created /tmp/pyboolnet_ahj5wbvb
# INFO created /tmp/pyboolnet_lbvdyasu
# INFO created /tmp/pyboolnet_1u29pxwp
# INFO created /tmp/pyboolnet_09c89rj6
# INFO created /tmp/pyboolnet_ihubcuo5
# INFO created /tmp/pyboolnet_pmx8ofme
# INFO created /tmp/pyboolnet_i5oued_r
# INFO created /tmp/pyboolnet_dr9d_2mv
# INFO created /tmp/pyboolnet_onn74iwm
# INFO created /tmp/pyboolnet__j7_phat
# INFO created /tmp/pyboolnet_a2otctp_
# INFO created /tmp/pyboolnet_ylgkoqps
# INFO created /tmp/pyboolnet_211ryvvy
# INFO created /tmp/pyboolnet_k214rrd1
# INFO created /tmp/pyboolnet_wrdkgc7y
# INFO created /tmp/pyboolnet_qjijs_36
# INFO created /tmp/pyboolnet_kew8so74
# INFO created /tmp/pyboolnet_8ekc4p7j
# INFO created /tmp/pyboolnet_0dg3twrc
# INFO created /tmp/pyboolnet_a8ltpgd9
# INFO created /tmp/pyboolnet_07k4mxoi
# INFO created /tmp/pyboolnet_6otvn0kg
# INFO created /tmp/pyboolnet_ga2yif8w
# INFO created /tmp/pyboolnet_xtmawtdo
# INFO created /tmp/pyboolnet_8_bb9r6t
# INFO created /tmp/pyboolnet_lx7x9_gm
# INFO created /tmp/pyboolnet_ycfgmefj
# INFO created /tmp/pyboolnet_e5oi70o3
# INFO created /tmp/pyboolnet_ugxh_x15
# INFO created /tmp/pyboolnet_w9g4ebwa
# INFO created /tmp/pyboolnet_e9nm9dih
# INFO created /tmp/pyboolnet_9rpkw7n9
# INFO created /tmp/pyboolnet_i86sv_et
# INFO created /tmp/pyboolnet_si1bo_s4
# INFO created /tmp/pyboolnet_jpjjf37x
# INFO created /tmp/pyboolnet_pwnueuro
# INFO created /tmp/pyboolnet_fsw13v96
# INFO created /tmp/pyboolnet_cezvmrvx
# INFO created /tmp/pyboolnet_7dfbbdhc
# INFO created /tmp/pyboolnet_bqz3o0g6
# INFO created /tmp/pyboolnet_el750tu4
# INFO created /tmp/pyboolnet_8x_pt3_o
# INFO created /tmp/pyboolnet_orqo856w
# INFO created /tmp/pyboolnet_efv5jj00
# INFO created /tmp/pyboolnet_hpoqgm9j
# INFO created /tmp/pyboolnet_t3_7dm10
# INFO created /tmp/pyboolnet_8f8o_ag3
# INFO created /tmp/pyboolnet_qz2p3meo
# INFO created /tmp/pyboolnet_gweepgsj
# INFO created /tmp/pyboolnet_22ul0og_
# INFO created /tmp/pyboolnet_pbmqjlz8
# INFO created /tmp/pyboolnet_rkm8jzsp
# INFO created /tmp/pyboolnet_f__zvz0j
# INFO created /tmp/pyboolnet_kduv8oqc
# INFO created /tmp/pyboolnet_yn5ky_ja
# INFO created /tmp/pyboolnet_yz468v09
# INFO created /tmp/pyboolnet_hk356x3i
# INFO created /tmp/pyboolnet_tfjl87zt
# INFO created /tmp/pyboolnet_75i_14lu
# INFO created /tmp/pyboolnet_n8m2igj7
# INFO created /tmp/pyboolnet_a6l0nv6d
# INFO created /tmp/pyboolnet_slzm6_km
# INFO created /tmp/pyboolnet_7hyg1pp8
# INFO created /tmp/pyboolnet_wfnjh9ef
# INFO created /tmp/pyboolnet_5d17icsb
# INFO created /tmp/pyboolnet_1h8lho2f
# INFO created /tmp/pyboolnet_kfdqh64n
# INFO created /tmp/pyboolnet_2v3d3bay
# ...
# INFO created /tmp/pyboolnet_g5078y66
# INFO created /tmp/pyboolnet_pnw797cl
# INFO created /tmp/pyboolnet__b1c1uu8
# INFO created /tmp/pyboolnet_xpousw9u
# INFO created /tmp/pyboolnet_qlrr3e_z
# INFO created /tmp/pyboolnet_0yewgcl6
# INFO created /tmp/pyboolnet_rbp4cyhk
# INFO created /tmp/pyboolnet_85hgnq38
# INFO created /tmp/pyboolnet_aa2rrf2r
# INFO created /tmp/pyboolnet_ejvur71r
# INFO created /tmp/pyboolnet_1ugfjha4
# INFO created /tmp/pyboolnet_s357pwrh
# INFO created /tmp/pyboolnet_j3ffhkeq
# INFO created /tmp/pyboolnet_89nkr6pq
# INFO created /tmp/pyboolnet_yf43q19r
# INFO created /tmp/pyboolnet_rl_z6fkm
# INFO created /tmp/pyboolnet_iihytohq
# INFO created /tmp/pyboolnet_naa0wed3
# INFO created /tmp/pyboolnet_gcz1f3oi
# INFO created /tmp/pyboolnet_vjw3fs37
# INFO created /tmp/pyboolnet_grmja2e3
# INFO created /tmp/pyboolnet_7nw2btha
# INFO created /tmp/pyboolnet_iac8f3pt
# INFO created /tmp/pyboolnet_1o13nxw9
# INFO created /tmp/pyboolnet_c03vgpbh
# INFO created /tmp/pyboolnet_b55h05k2
# INFO created /tmp/pyboolnet_dfuf3vfe
# INFO created /tmp/pyboolnet_glbvye6b
# INFO created /tmp/pyboolnet_ufoiq2ti
# INFO created /tmp/pyboolnet__s1pu1m_
# INFO created /tmp/pyboolnet_b8_qinp5
# INFO created /tmp/pyboolnet_86n0vinz
# INFO created /tmp/pyboolnet_jx_gb9fg
# INFO created /tmp/pyboolnet_4b7bci6m
# INFO created /tmp/pyboolnet_kesgfb7_
# INFO created /tmp/pyboolnet_80czvqwa
# INFO created /tmp/pyboolnet_tle40sor
# INFO created /tmp/pyboolnet_o59nl1ht
# INFO created /tmp/pyboolnet_sror_dai
# INFO created /tmp/pyboolnet_s3hmlefz
# INFO created /tmp/pyboolnet_rcmohq_s
# INFO created /tmp/pyboolnet_jz2lwf26
# INFO created /tmp/pyboolnet_9a_6kckp
# INFO created /tmp/pyboolnet_mcgrky5r
# INFO created /tmp/pyboolnet_yr1aww_q
# INFO created /tmp/pyboolnet__e4ncs81
# INFO created /tmp/pyboolnet_dzss_99w
# INFO created /tmp/pyboolnet__dv2hf82
# INFO created /tmp/pyboolnet_4d0ytti1
# INFO created /tmp/pyboolnet_9dc3m2lh
# INFO created /tmp/pyboolnet_un_fj2tb
# INFO created /tmp/pyboolnet_1k5jss8q
# INFO created /tmp/pyboolnet_wg33o7fa
# INFO created /tmp/pyboolnet_axvzgivz
# INFO created /tmp/pyboolnet_ztrus7sl
# INFO created /tmp/pyboolnet_914xa5q5
# INFO created /tmp/pyboolnet_1whhjlrg
# INFO created /tmp/pyboolnet_jwejggu7
# INFO created /tmp/pyboolnet__2vvfraa
# INFO created /tmp/pyboolnet_sc0l4jap
# INFO created /tmp/pyboolnet_596bn_se
# INFO created /tmp/pyboolnet_qore49kd
# INFO created /tmp/pyboolnet_pr7x6d13
# INFO created /tmp/pyboolnet_gbg2224e
# INFO created /tmp/pyboolnet_sn_rxgh2
# INFO created /tmp/pyboolnet_6ms0xy5x
# INFO created /tmp/pyboolnet_ccvirlnb
# INFO created /tmp/pyboolnet_ellgd5sk
# INFO created /tmp/pyboolnet_n4h91981
# INFO created /tmp/pyboolnet_dbr0e8s7
# INFO created /tmp/pyboolnet_opagye04
# INFO created /tmp/pyboolnet_p6h3wlq0
# INFO created /tmp/pyboolnet_h648hhyn
# INFO created /tmp/pyboolnet_0jispk8t
# INFO created /tmp/pyboolnet_fcctkned
# INFO created /tmp/pyboolnet_cme2jdgh
# INFO created /tmp/pyboolnet_bjidjoff
# INFO created /tmp/pyboolnet_w1ubw_06
# INFO created /tmp/pyboolnet_xni0yl76
# INFO created /tmp/pyboolnet_gnl1n76c
# INFO created /tmp/pyboolnet_d5vjp117
# INFO created /tmp/pyboolnet_allzmjw7
# INFO created /tmp/pyboolnet_2g7esohc
# INFO created /tmp/pyboolnet_a_i9rwzl
# INFO created /tmp/pyboolnet_yyo1spvb
# INFO created /tmp/pyboolnet_2_qvwnvl
# INFO created /tmp/pyboolnet_4dhveiwu
# INFO created /tmp/pyboolnet_mlrjhyyl
# INFO created /tmp/pyboolnet_o_9ztvvn
# INFO created /tmp/pyboolnet_mw0_06oy
# INFO created /tmp/pyboolnet_26jj2tj2
# INFO created /tmp/pyboolnet_vfa9p8e7
# INFO created /tmp/pyboolnet_i9uvg3b3
# INFO created /tmp/pyboolnet_g7pal5a6
# INFO created /tmp/pyboolnet_xvygz52h
# INFO created /tmp/pyboolnet_j0y08ngv
# INFO created /tmp/pyboolnet_uuakndes
# INFO created /tmp/pyboolnet_j97ksh22
# INFO created /tmp/pyboolnet_3i5g9rji
# INFO created /tmp/pyboolnet_do0hndqi
# INFO created /tmp/pyboolnet_afxzl4b9
# INFO created /tmp/pyboolnet_wry_uihi
# INFO created /tmp/pyboolnet_6xrjn1n9
# INFO created /tmp/pyboolnet_lucubmyd
# INFO created /tmp/pyboolnet_oqgkx4yn
# INFO created /tmp/pyboolnet__jlc8_jh
# INFO created /tmp/pyboolnet_up9gww6g
# INFO created /tmp/pyboolnet_82rlb5ei
# INFO created /tmp/pyboolnet_f0eiget_
# INFO created /tmp/pyboolnet_ktfensjg
# INFO created /tmp/pyboolnet_jwyjk2cr
# INFO created /tmp/pyboolnet_7u6jgpzj
# INFO created /tmp/pyboolnet_9sdj_uci
# INFO created /tmp/pyboolnet_ue0_qxvl
# INFO created /tmp/pyboolnet_9e7161ay
# INFO created /tmp/pyboolnet_fdbrisoc
# INFO created /tmp/pyboolnet_a7aql_ih
# INFO created /tmp/pyboolnet_myo9b5el
# INFO created /tmp/pyboolnet_25yklsb5
# INFO created /tmp/pyboolnet_szmr1x10
# INFO created /tmp/pyboolnet_7daccs3p
# INFO created /tmp/pyboolnet_drr9c9x7
# INFO created /tmp/pyboolnet_8vdc0vci
# INFO created /tmp/pyboolnet_bumddu3m
# INFO created /tmp/pyboolnet_1mqfawo2
# INFO created /tmp/pyboolnet_9h0qn4lp
# INFO created /tmp/pyboolnet_qyo50zyl
# INFO created /tmp/pyboolnet_0okjd6od
# INFO created /tmp/pyboolnet_nkm4hvrr
# INFO created /tmp/pyboolnet_1nc9j9wf
# INFO created /tmp/pyboolnet_3un_km3g
# INFO created /tmp/pyboolnet_s3i6xuxk
# INFO created /tmp/pyboolnet_heeuww4m
# INFO created /tmp/pyboolnet_rdks90uv
# INFO created /tmp/pyboolnet_8q1map8d
# INFO created /tmp/pyboolnet_oooqxrd5
# INFO created /tmp/pyboolnet_tq3_fxjq
# INFO created /tmp/pyboolnet_j131dnyl
# INFO created /tmp/pyboolnet_wzudecyr
# INFO created /tmp/pyboolnet_i9bhv75r
# INFO created /tmp/pyboolnet_trcaznl9
# INFO created /tmp/pyboolnet_q7vc9aoz
# INFO created /tmp/pyboolnet_6odfcmlx
# INFO created /tmp/pyboolnet_gq738oao
# INFO created /tmp/pyboolnet_n4nufo5i
# INFO created /tmp/pyboolnet_l39t4q4t
# INFO created /tmp/pyboolnet_c6bk_eai
# INFO created /tmp/pyboolnet_9go_lv4o
# INFO created /tmp/pyboolnet_iphbxlza
# INFO created /tmp/pyboolnet_hglg0fv6
# INFO created /tmp/pyboolnet_3z7vlr8q
# INFO created /tmp/pyboolnet_8u3hdtf1
# INFO created /tmp/pyboolnet_3r6j4js_
# INFO created /tmp/pyboolnet_6e9y5p_t
# INFO created /tmp/pyboolnet_q828b1mh
# INFO created /tmp/pyboolnet_yo3kmw0e
# INFO created /tmp/pyboolnet_ac0gapr6
# INFO created /tmp/pyboolnet_5ohtv9m_
# INFO created /tmp/pyboolnet_y174ny9q
# INFO created /tmp/pyboolnet_jla3ds60
# INFO created /tmp/pyboolnet_q3sxqysz
# INFO created /tmp/pyboolnet__m7ayzkc
# INFO created /tmp/pyboolnet_3e8v7a34
# INFO created /tmp/pyboolnet__dlp7nh1
# INFO created /tmp/pyboolnet_59tgwpka
# INFO created /tmp/pyboolnet_qnutuj4e
# INFO created /tmp/pyboolnet_kohc0llw
# INFO created /tmp/pyboolnet_6os9rqog
# INFO created /tmp/pyboolnet_3dln047w
# INFO created /tmp/pyboolnet_uwvffadl
# INFO created /tmp/pyboolnet_k6acooe2
# INFO created /tmp/pyboolnet_nbvgi2o6
# INFO created /tmp/pyboolnet_visis0or
# INFO created /tmp/pyboolnet_dhyggqt4
# INFO created /tmp/pyboolnet_odnhkl5d
# INFO created /tmp/pyboolnet_6x3b0oah
# INFO created /tmp/pyboolnet_490nw4o4
# INFO created /tmp/pyboolnet_pwyec12o
# INFO created /tmp/pyboolnet_u_2a7uva
# INFO created /tmp/pyboolnet_acwh6xsr
# INFO created /tmp/pyboolnet_zbd447wt
# INFO created /tmp/pyboolnet_mko880r6
# INFO created /tmp/pyboolnet_61uva8p2
# INFO created /tmp/pyboolnet_og3m50a3
# INFO created /tmp/pyboolnet_2iigtr4d
# INFO created /tmp/pyboolnet_i5ptgbx3
# INFO created /tmp/pyboolnet_tz29d3x0
# INFO created /tmp/pyboolnet_93uriquf
# INFO created /tmp/pyboolnet_9a99xu7c
# INFO created /tmp/pyboolnet_2m7j5cyh
# INFO created /tmp/pyboolnet_2f50eyvd
# INFO created /tmp/pyboolnet_td7rka3i
# INFO created /tmp/pyboolnet_ih4hcfpo
# INFO created /tmp/pyboolnet_qtg8v3jt
# INFO created /tmp/pyboolnet_dc74a4bb
# INFO created /tmp/pyboolnet_7dsofypc
# INFO created /tmp/pyboolnet_4kbbqo3q
# INFO created /tmp/pyboolnet_fvbzswko
# INFO created /tmp/pyboolnet_on2awotr
# INFO created /tmp/pyboolnet_118xpimz
# INFO created /tmp/pyboolnet_rxh66mj1
# INFO created /tmp/pyboolnet_rg8yg885
# INFO created /tmp/pyboolnet_n9smlsuj
# INFO created /tmp/pyboolnet_p9t2jabi
# INFO created /tmp/pyboolnet_4aako65d
# INFO created /tmp/pyboolnet_6h_s425r
# INFO created /tmp/pyboolnet_nzc98c34
# INFO created /tmp/pyboolnet_jia6kfnl
# INFO created /tmp/pyboolnet_3wrq53f3
# INFO created /tmp/pyboolnet_7ph7k3q6
# INFO created /tmp/pyboolnet_6q8wxxu_
# INFO created /tmp/pyboolnet_jp75hozx
# INFO created /tmp/pyboolnet_hz1kvvlm
# INFO created /tmp/pyboolnet_22m4xkhp
# INFO created /tmp/pyboolnet_pyzna5s6
# INFO created /tmp/pyboolnet_ox5qj179
# INFO created /tmp/pyboolnet_mr6llmwr
# INFO created /tmp/pyboolnet_y2rfaq7y
# INFO created /tmp/pyboolnet_lg_93kqp
# INFO created /tmp/pyboolnet_wyin635f
# INFO created /tmp/pyboolnet_2q1s08wn
# INFO created /tmp/pyboolnet_diwzg47e
# INFO created /tmp/pyboolnet_xtlbbhlk
# INFO created /tmp/pyboolnet_h6tsgrjw
# INFO created /tmp/pyboolnet_nbywhwt2
# INFO created /tmp/pyboolnet_ki_zx8y4
# INFO created /tmp/pyboolnet_2jxikg9g
# INFO created /tmp/pyboolnet_57v9kh4w
# INFO created /tmp/pyboolnet_g6n2r_z_
# INFO created /tmp/pyboolnet_gbqaktzf
# INFO created /tmp/pyboolnet_pe2v8okj
# INFO created /tmp/pyboolnet_g9pii5rg
# INFO created /tmp/pyboolnet_edrjhp0i
# INFO created /tmp/pyboolnet_ka_j8357
# INFO created /tmp/pyboolnet_1kv0m_g8
# INFO created /tmp/pyboolnet_m77zgx69
# INFO created /tmp/pyboolnet_mbi04bue
# INFO created /tmp/pyboolnet_y_mlbirf
# INFO created /tmp/pyboolnet_g6pda_ie
# INFO created /tmp/pyboolnet__2eylje3
# INFO created /tmp/pyboolnet_p4sacp6x
# INFO created /tmp/pyboolnet_6yr4mkaw
# INFO created /tmp/pyboolnet_zjzbq4b1
# INFO created /tmp/pyboolnet_ph3x5ihw
# INFO created /tmp/pyboolnet_ezp89ets
# INFO created /tmp/pyboolnet_1zpcv2tl
# INFO created /tmp/pyboolnet_x0wg7ktt
# INFO created /tmp/pyboolnet_x_m281rw
# INFO created /tmp/pyboolnet_npyqys3r
# INFO created /tmp/pyboolnet_h_lpfxh3
# INFO created /tmp/pyboolnet_y7sjaymh
# INFO created /tmp/pyboolnet_0sm0clli
# INFO created /tmp/pyboolnet_pvsw3kw0
# INFO created /tmp/pyboolnet_0rua_f62
# INFO created /tmp/pyboolnet_goztvjmx
# INFO created /tmp/pyboolnet_6l9s5gzn
# INFO created /tmp/pyboolnet_0p44jx3n
# INFO created /tmp/pyboolnet_v0o0mgox
# INFO created /tmp/pyboolnet_rq6w871s
# INFO created /tmp/pyboolnet_ebu8ly5k
# INFO created /tmp/pyboolnet_sm1v6rad
# INFO created /tmp/pyboolnet_g7k1ucj_
# INFO created /tmp/pyboolnet_3nxgmqwg
# INFO created /tmp/pyboolnet_lj3nba3l
# INFO created /tmp/pyboolnet_39pqhhzg
# INFO created /tmp/pyboolnet_hho2f40n
# INFO created /tmp/pyboolnet_jcm5eqv7
# INFO created /tmp/pyboolnet_qw06v_48
# INFO created /tmp/pyboolnet_u9nvvsm4
# INFO created /tmp/pyboolnet_99pc4kqp
# INFO created /tmp/pyboolnet_os8hemyp
# INFO created /tmp/pyboolnet_5yxzhmvk
# INFO created /tmp/pyboolnet_pg5wkt4_
# INFO created /tmp/pyboolnet_bg_0g4rk
# INFO created /tmp/pyboolnet_b4xonyq0
# INFO created /tmp/pyboolnet_z85gh6e4
# INFO created /tmp/pyboolnet_imya06d_
# INFO created /tmp/pyboolnet_fnl70b06
# INFO created /tmp/pyboolnet_zejlsp1r
# INFO created /tmp/pyboolnet_rzh9r3w3
# INFO created /tmp/pyboolnet_51yfgj96
# INFO created /tmp/pyboolnet_tixasqfb
# INFO created /tmp/pyboolnet_ka958b7r
# INFO created /tmp/pyboolnet_yj3k4j1y
# INFO created /tmp/pyboolnet_y7fiiy52
# INFO created /tmp/pyboolnet_6skof6q4
# INFO created /tmp/pyboolnet_nykop54s
# INFO created /tmp/pyboolnet_kf1gf2db
# INFO created /tmp/pyboolnet_ii6ysmlp
# INFO created /tmp/pyboolnet_opqugl4a
# INFO created /tmp/pyboolnet_oettq8z1
# INFO created /tmp/pyboolnet_pwm7j99u
# INFO created /tmp/pyboolnet_20fk9l55
# INFO created /tmp/pyboolnet_niwqje_x
# INFO created /tmp/pyboolnet__x81glbs
# INFO created /tmp/pyboolnet_k0jly5sc
# INFO created /tmp/pyboolnet_wx_yr1eu
# INFO created /tmp/pyboolnet_44_v5kxm
# INFO created /tmp/pyboolnet_uqusugd6
# INFO created /tmp/pyboolnet_1_zvox_3
# INFO created /tmp/pyboolnet_7a6kggdc
# INFO created /tmp/pyboolnet__tx57kiw
# INFO created /tmp/pyboolnet_x13eqlxf
# INFO created /tmp/pyboolnet_iolz1uyj
# INFO created /tmp/pyboolnet_gypq5n0u
# INFO created /tmp/pyboolnet_4wn8zw7y
# INFO created /tmp/pyboolnet_pr5ndzeb
# INFO created /tmp/pyboolnet_6n7gn5rl
# INFO created /tmp/pyboolnet_pbus6h81
# INFO created /tmp/pyboolnet_0m42nfc8
# INFO created /tmp/pyboolnet_3pbujhhf
# INFO created /tmp/pyboolnet_kfqysota
# INFO created /tmp/pyboolnet_ld9e3oua
# INFO created /tmp/pyboolnet_bo92n2se
# INFO created /tmp/pyboolnet_0tri34se
# INFO created /tmp/pyboolnet_05h2y7eo
# INFO created /tmp/pyboolnet_a5q3i7ob
# INFO created /tmp/pyboolnet_6tjg6606
# INFO created /tmp/pyboolnet_ppd7ihot
# INFO created /tmp/pyboolnet_lsw8x0ew
# INFO created /tmp/pyboolnet_96rpw7k_
# INFO created /tmp/pyboolnet_4ppit5bb
# INFO created /tmp/pyboolnet_uoiq9ouf
# INFO created /tmp/pyboolnet_bxhbwyqd
# INFO created /tmp/pyboolnet_gtat2x1q
# INFO created /tmp/pyboolnet_iqtcl7cr
# INFO created /tmp/pyboolnet_hux9rcmq
# INFO created /tmp/pyboolnet_18se0it1
# INFO created /tmp/pyboolnet_bxb6cs6p
# INFO created /tmp/pyboolnet_2c2e2o2y
# INFO created /tmp/pyboolnet_77kub8br
# INFO created /tmp/pyboolnet_6tlys8mr
# INFO created /tmp/pyboolnet_oa6xp08r
# INFO created /tmp/pyboolnet_dg5dxpwu
# INFO created /tmp/pyboolnet_5h61pxta
# INFO created /tmp/pyboolnet_ervobh1r
# INFO created /tmp/pyboolnet_i89sc_16
# INFO created /tmp/pyboolnet_m870d7qj
# INFO created /tmp/pyboolnet_jpqs9a58
# INFO created /tmp/pyboolnet_14i5c42j
# INFO created /tmp/pyboolnet_p0ghczdf
# INFO created /tmp/pyboolnet_p_fi8adg
# INFO created /tmp/pyboolnet_hbuvd9hk
# INFO created /tmp/pyboolnet_d_ahw8k5
# INFO created /tmp/pyboolnet_q4n0wyah
# INFO created /tmp/pyboolnet_nej5ggzr
# INFO created /tmp/pyboolnet_z_6wt6qu
# INFO created /tmp/pyboolnet_9cl21cw_
# INFO created /tmp/pyboolnet_2ey1w0l5
# INFO created /tmp/pyboolnet_lxf2dwjf
# INFO created /tmp/pyboolnet_r7b8cvg9
# INFO created /tmp/pyboolnet_jbwuy8hq
# INFO created /tmp/pyboolnet_v1dg8iq2
# INFO created /tmp/pyboolnet_uwg_kb_v
# INFO created /tmp/pyboolnet_u31nau5q
# INFO created /tmp/pyboolnet_4hpaio1y
# INFO created /tmp/pyboolnet_w4mqp2qr
# INFO created /tmp/pyboolnet_kre3wv0d
# INFO created /tmp/pyboolnet_7nu_3xqg
# INFO created /tmp/pyboolnet_j102pz8y
# INFO created /tmp/pyboolnet_ru8k78pw
# INFO created /tmp/pyboolnet_1s6sg6pf
# INFO created /tmp/pyboolnet_alnuphi5
# INFO created /tmp/pyboolnet_lss__53v
# INFO created /tmp/pyboolnet_se8y2wt8
# INFO created /tmp/pyboolnet_ntqbswtb
# INFO created /tmp/pyboolnet_y0uky0lo
# INFO created /tmp/pyboolnet_t2brin2r
# INFO created /tmp/pyboolnet_mhl5q1bh
# INFO created /tmp/pyboolnet_kyc2w7t3
# INFO created /tmp/pyboolnet_1r2s598x
# INFO created /tmp/pyboolnet_o7_5oqp_
# INFO created /tmp/pyboolnet_n6hycw9c
# INFO created /tmp/pyboolnet_gpn91wfs
# INFO created /tmp/pyboolnet_z_ykc2si
# INFO created /tmp/pyboolnet_fg0qky41
# INFO created /tmp/pyboolnet_tah8g65l
# INFO created /tmp/pyboolnet_ffsqa46q
# INFO created /tmp/pyboolnet_p809xh94
# INFO created /tmp/pyboolnet_fwv0k3io
# INFO created /tmp/pyboolnet_kwnt_2jh
# INFO created /tmp/pyboolnet_3j9j20vx
# INFO created /tmp/pyboolnet_b8d3slw1
# INFO created /tmp/pyboolnet_0xrdbjld
# INFO created /tmp/pyboolnet_66zomjcw
# INFO created /tmp/pyboolnet_ljyo_rd0
# INFO created /tmp/pyboolnet_3znk1b96
# INFO created /tmp/pyboolnet_sdm8famq
# INFO created /tmp/pyboolnet_uxdwjjmq
# INFO created /tmp/pyboolnet_d50wv5kz
# INFO created /tmp/pyboolnet_kb1x_p12
# INFO created /tmp/pyboolnet_u1rpv3g0
# INFO created /tmp/pyboolnet_v8mz6t0h
# INFO created /tmp/pyboolnet_8fz2acta
# INFO created /tmp/pyboolnet_6fwepm1o
# INFO created /tmp/pyboolnet_r0mus10n
# INFO created /tmp/pyboolnet_1_qvwkg2
# INFO created /tmp/pyboolnet_5chy4laz
# INFO created /tmp/pyboolnet_n4pj8wvd
# INFO created /tmp/pyboolnet_lgxgzdn2
# INFO created /tmp/pyboolnet_do7brvck
# INFO created /tmp/pyboolnet_sjyra8l5
# INFO created /tmp/pyboolnet_lcstjbk3
# INFO created /tmp/pyboolnet_kdmt4mxg
# INFO created /tmp/pyboolnet_o9ity614
# INFO created /tmp/pyboolnet_ix3ok5b1
# INFO created /tmp/pyboolnet_9gcos0x5
# INFO created /tmp/pyboolnet_9y648u0k
# INFO created /tmp/pyboolnet_x1ajju8v
# INFO created /tmp/pyboolnet_2uw651q7
# INFO created /tmp/pyboolnet_5dk0ggd0
# INFO created /tmp/pyboolnet_fmqqz_2d
# INFO created /tmp/pyboolnet_75qxrb_2
# INFO created /tmp/pyboolnet_r0o9zzey
# INFO created /tmp/pyboolnet_0r6a8xpi
# INFO created /tmp/pyboolnet_1aumfm5k
# INFO created /tmp/pyboolnet_5_3fy6ol
# INFO created /tmp/pyboolnet_mjk9v4tf
# INFO created /tmp/pyboolnet_1bgy1aj8
# INFO created /tmp/pyboolnet_k50oe0rk
# INFO created /tmp/pyboolnet_b57jl0uq
# INFO created /tmp/pyboolnet_oxhovvc3
# INFO created /tmp/pyboolnet_9aqrk9ki
# INFO created /tmp/pyboolnet_ifdf1koy
# INFO created /tmp/pyboolnet_kq3yamf5
# INFO created /tmp/pyboolnet_8emz1jqo
# INFO created /tmp/pyboolnet_wvefgiyk
# INFO created /tmp/pyboolnet_yzln70o6
# INFO created /tmp/pyboolnet_5zyb82os
# INFO created /tmp/pyboolnet__dkjf50y
# INFO created /tmp/pyboolnet_awzepv6w
# INFO created /tmp/pyboolnet_bsh9lqws

# %%
# Identifying models with different attractors reachability than the asynchronous dynamics
asyn_diff = [m for m in models[1:] if answer["ASYN"] != answer[m]]
asyn_diff
# Out:
# ['Bclaf1_Cebpa_Egr1_Fli1',
#  'Bclaf1_Cebpa_Egr1_Gata2',
#  'Bclaf1_Cebpa_Egr1_Spi1',
#  'Bclaf1_Cebpa_Fli1_Gata1',
#  'Bclaf1_Cebpa_Fli1_Gata2',
#  'Bclaf1_Cebpa_Fli1_Ikzf1',
#  'Bclaf1_Cebpa_Fli1_Junb',
#  'Bclaf1_Cebpa_Fli1_Klf1',
#  'Bclaf1_Cebpa_Fli1_Myc',
#  'Bclaf1_Cebpa_Fli1_Spi1',
#  'Bclaf1_Cebpa_Fli1_Zfpm1',
#  'Bclaf1_Cebpa_Gata1_Gata2',
#  'Bclaf1_Cebpa_Gata1_Spi1',
#  'Bclaf1_Cebpa_Gata2_Ikzf1',
#  'Bclaf1_Cebpa_Gata2_Junb',
#  'Bclaf1_Cebpa_Gata2_Klf1',
#  'Bclaf1_Cebpa_Gata2_Myc',
#  'Bclaf1_Cebpa_Gata2_Spi1',
#  'Bclaf1_Cebpa_Gata2_Zfpm1',
#  'Bclaf1_Cebpa_Ikzf1_Spi1',
#  'Bclaf1_Cebpa_Junb_Spi1',
#  'Bclaf1_Cebpa_Klf1_Spi1',
#  'Bclaf1_Cebpa_Myc_Spi1',
#  'Bclaf1_Cebpa_Spi1_Zfpm1',
#  'Bclaf1_Egr1_Fli1_Gata1',
#  'Bclaf1_Egr1_Fli1_Gata2',
#  'Bclaf1_Egr1_Fli1_Ikzf1',
#  'Bclaf1_Egr1_Fli1_Junb',
#  'Bclaf1_Egr1_Fli1_Klf1',
#  'Bclaf1_Egr1_Fli1_Myc',
#  'Bclaf1_Egr1_Fli1_Spi1',
#  'Bclaf1_Egr1_Fli1_Zfpm1',
#  'Bclaf1_Egr1_Gata1_Gata2',
#  'Bclaf1_Egr1_Gata1_Spi1',
#  'Bclaf1_Egr1_Gata2_Ikzf1',
#  'Bclaf1_Egr1_Gata2_Junb',
#  'Bclaf1_Egr1_Gata2_Klf1',
#  'Bclaf1_Egr1_Gata2_Myc',
#  'Bclaf1_Egr1_Gata2_Spi1',
#  'Bclaf1_Egr1_Gata2_Zfpm1',
#  'Bclaf1_Egr1_Ikzf1_Spi1',
#  'Bclaf1_Egr1_Junb_Spi1',
#  'Bclaf1_Egr1_Klf1_Spi1',
#  'Bclaf1_Egr1_Myc_Spi1',
#  'Bclaf1_Egr1_Spi1_Zfpm1',
#  'Bclaf1_Fli1_Gata1_Gata2',
#  'Bclaf1_Fli1_Gata1_Ikzf1',
#  'Bclaf1_Fli1_Gata1_Junb',
#  'Bclaf1_Fli1_Gata1_Klf1',
#  'Bclaf1_Fli1_Gata1_Myc',
#  'Bclaf1_Fli1_Gata1_Spi1',
#  'Bclaf1_Fli1_Gata1_Zfpm1',
#  'Bclaf1_Fli1_Gata2_Ikzf1',
#  'Bclaf1_Fli1_Gata2_Junb',
#  'Bclaf1_Fli1_Gata2_Klf1',
#  'Bclaf1_Fli1_Gata2_Myc',
#  'Bclaf1_Fli1_Gata2_Spi1',
#  'Bclaf1_Fli1_Gata2_Zfpm1',
#  'Bclaf1_Fli1_Ikzf1_Junb',
#  'Bclaf1_Fli1_Ikzf1_Klf1',
#  'Bclaf1_Fli1_Ikzf1_Myc',
#  'Bclaf1_Fli1_Ikzf1_Spi1',
#  'Bclaf1_Fli1_Ikzf1_Zfpm1',
#  'Bclaf1_Fli1_Junb_Klf1',
#  'Bclaf1_Fli1_Junb_Myc',
#  'Bclaf1_Fli1_Junb_Spi1',
#  'Bclaf1_Fli1_Junb_Zfpm1',
#  'Bclaf1_Fli1_Klf1_Myc',
#  'Bclaf1_Fli1_Klf1_Spi1',
#  'Bclaf1_Fli1_Klf1_Zfpm1',
#  'Bclaf1_Fli1_Myc_Spi1',
#  'Bclaf1_Fli1_Myc_Zfpm1',
#  'Bclaf1_Fli1_Spi1_Zfpm1',
#  'Bclaf1_Gata1_Gata2_Ikzf1',
#  'Bclaf1_Gata1_Gata2_Junb',
#  'Bclaf1_Gata1_Gata2_Klf1',
#  'Bclaf1_Gata1_Gata2_Myc',
#  'Bclaf1_Gata1_Gata2_Spi1',
#  'Bclaf1_Gata1_Gata2_Zfpm1',
#  'Bclaf1_Gata1_Ikzf1_Spi1',
#  'Bclaf1_Gata1_Junb_Spi1',
#  'Bclaf1_Gata1_Klf1_Spi1',
#  'Bclaf1_Gata1_Myc_Spi1',
#  'Bclaf1_Gata1_Spi1_Zfpm1',
#  'Bclaf1_Gata2_Ikzf1_Junb',
#  'Bclaf1_Gata2_Ikzf1_Klf1',
#  'Bclaf1_Gata2_Ikzf1_Myc',
#  'Bclaf1_Gata2_Ikzf1_Spi1',
#  'Bclaf1_Gata2_Ikzf1_Zfpm1',
#  'Bclaf1_Gata2_Junb_Klf1',
#  'Bclaf1_Gata2_Junb_Myc',
#  'Bclaf1_Gata2_Junb_Spi1',
#  'Bclaf1_Gata2_Junb_Zfpm1',
#  'Bclaf1_Gata2_Klf1_Myc',
#  'Bclaf1_Gata2_Klf1_Spi1',
#  'Bclaf1_Gata2_Klf1_Zfpm1',
#  'Bclaf1_Gata2_Myc_Spi1',
#  'Bclaf1_Gata2_Myc_Zfpm1',
#  'Bclaf1_Gata2_Spi1_Zfpm1',
#  'Bclaf1_Ikzf1_Junb_Spi1',
#  'Bclaf1_Ikzf1_Klf1_Spi1',
#  'Bclaf1_Ikzf1_Myc_Spi1',
#  'Bclaf1_Ikzf1_Spi1_Zfpm1',
#  'Bclaf1_Junb_Klf1_Spi1',
#  'Bclaf1_Junb_Myc_Spi1',
#  'Bclaf1_Junb_Spi1_Zfpm1',
#  'Bclaf1_Klf1_Myc_Spi1',
#  'Bclaf1_Klf1_Spi1_Zfpm1',
#  'Bclaf1_Myc_Spi1_Zfpm1',
#  'Cebpa_Egr1_Fli1_Gata1',
#  'Cebpa_Egr1_Fli1_Gata2',
#  'Cebpa_Egr1_Fli1_Ikzf1',
#  'Cebpa_Egr1_Fli1_Junb',
#  'Cebpa_Egr1_Fli1_Klf1',
#  'Cebpa_Egr1_Fli1_Myc',
#  'Cebpa_Egr1_Fli1_Spi1',
#  'Cebpa_Egr1_Fli1_Zfpm1',
#  'Cebpa_Egr1_Gata1_Gata2',
#  'Cebpa_Egr1_Gata1_Spi1',
#  'Cebpa_Egr1_Gata2_Ikzf1',
#  'Cebpa_Egr1_Gata2_Junb',
#  'Cebpa_Egr1_Gata2_Klf1',
#  'Cebpa_Egr1_Gata2_Myc',
#  'Cebpa_Egr1_Gata2_Spi1',
#  'Cebpa_Egr1_Gata2_Zfpm1',
#  'Cebpa_Egr1_Ikzf1_Spi1',
#  'Cebpa_Egr1_Junb_Spi1',
#  'Cebpa_Egr1_Klf1_Spi1',
#  'Cebpa_Egr1_Myc_Spi1',
#  'Cebpa_Egr1_Spi1_Zfpm1',
#  'Cebpa_Fli1_Gata1_Gata2',
#  'Cebpa_Fli1_Gata1_Ikzf1',
#  'Cebpa_Fli1_Gata1_Junb',
#  'Cebpa_Fli1_Gata1_Klf1',
#  'Cebpa_Fli1_Gata1_Myc',
#  'Cebpa_Fli1_Gata1_Spi1',
#  'Cebpa_Fli1_Gata1_Zfpm1',
#  'Cebpa_Fli1_Gata2_Ikzf1',
#  'Cebpa_Fli1_Gata2_Junb',
#  'Cebpa_Fli1_Gata2_Klf1',
#  'Cebpa_Fli1_Gata2_Myc',
#  'Cebpa_Fli1_Gata2_Spi1',
#  'Cebpa_Fli1_Gata2_Zfpm1',
#  'Cebpa_Fli1_Ikzf1_Junb',
#  'Cebpa_Fli1_Ikzf1_Klf1',
#  'Cebpa_Fli1_Ikzf1_Myc',
#  'Cebpa_Fli1_Ikzf1_Spi1',
#  'Cebpa_Fli1_Ikzf1_Zfpm1',
#  'Cebpa_Fli1_Junb_Klf1',
#  'Cebpa_Fli1_Junb_Myc',
#  'Cebpa_Fli1_Junb_Spi1',
#  'Cebpa_Fli1_Junb_Zfpm1',
#  'Cebpa_Fli1_Klf1_Myc',
#  'Cebpa_Fli1_Klf1_Spi1',
#  'Cebpa_Fli1_Klf1_Zfpm1',
#  'Cebpa_Fli1_Myc_Spi1',
#  'Cebpa_Fli1_Myc_Zfpm1',
#  'Cebpa_Fli1_Spi1_Zfpm1',
#  'Cebpa_Gata1_Gata2_Ikzf1',
#  'Cebpa_Gata1_Gata2_Junb',
#  'Cebpa_Gata1_Gata2_Klf1',
#  'Cebpa_Gata1_Gata2_Myc',
#  'Cebpa_Gata1_Gata2_Spi1',
#  'Cebpa_Gata1_Gata2_Zfpm1',
#  'Cebpa_Gata1_Ikzf1_Spi1',
#  'Cebpa_Gata1_Junb_Spi1',
#  'Cebpa_Gata1_Klf1_Spi1',
#  'Cebpa_Gata1_Myc_Spi1',
#  'Cebpa_Gata1_Spi1_Zfpm1',
#  'Cebpa_Gata2_Ikzf1_Junb',
#  'Cebpa_Gata2_Ikzf1_Klf1',
#  'Cebpa_Gata2_Ikzf1_Myc',
#  'Cebpa_Gata2_Ikzf1_Spi1',
#  'Cebpa_Gata2_Ikzf1_Zfpm1',
#  'Cebpa_Gata2_Junb_Klf1',
#  'Cebpa_Gata2_Junb_Myc',
#  'Cebpa_Gata2_Junb_Spi1',
#  'Cebpa_Gata2_Junb_Zfpm1',
#  'Cebpa_Gata2_Klf1_Myc',
#  'Cebpa_Gata2_Klf1_Spi1',
#  'Cebpa_Gata2_Klf1_Zfpm1',
#  'Cebpa_Gata2_Myc_Spi1',
#  'Cebpa_Gata2_Myc_Zfpm1',
#  'Cebpa_Gata2_Spi1_Zfpm1',
#  'Cebpa_Ikzf1_Junb_Spi1',
#  'Cebpa_Ikzf1_Klf1_Spi1',
#  'Cebpa_Ikzf1_Myc_Spi1',
#  'Cebpa_Ikzf1_Spi1_Zfpm1',
#  'Cebpa_Junb_Klf1_Spi1',
#  'Cebpa_Junb_Myc_Spi1',
#  'Cebpa_Junb_Spi1_Zfpm1',
#  'Cebpa_Klf1_Myc_Spi1',
#  'Cebpa_Klf1_Spi1_Zfpm1',
#  'Cebpa_Myc_Spi1_Zfpm1',
#  'Egr1_Fli1_Gata1_Gata2',
#  'Egr1_Fli1_Gata1_Ikzf1',
#  'Egr1_Fli1_Gata1_Junb',
#  'Egr1_Fli1_Gata1_Klf1',
#  'Egr1_Fli1_Gata1_Myc',
#  'Egr1_Fli1_Gata1_Spi1',
#  'Egr1_Fli1_Gata1_Zfpm1',
#  'Egr1_Fli1_Gata2_Ikzf1',
#  'Egr1_Fli1_Gata2_Junb',
#  'Egr1_Fli1_Gata2_Klf1',
#  'Egr1_Fli1_Gata2_Myc',
#  'Egr1_Fli1_Gata2_Spi1',
#  'Egr1_Fli1_Gata2_Zfpm1',
#  'Egr1_Fli1_Ikzf1_Junb',
#  'Egr1_Fli1_Ikzf1_Klf1',
#  'Egr1_Fli1_Ikzf1_Myc',
#  'Egr1_Fli1_Ikzf1_Spi1',
#  'Egr1_Fli1_Ikzf1_Zfpm1',
#  'Egr1_Fli1_Junb_Klf1',
#  'Egr1_Fli1_Junb_Myc',
#  'Egr1_Fli1_Junb_Spi1',
#  'Egr1_Fli1_Junb_Zfpm1',
#  'Egr1_Fli1_Klf1_Myc',
#  'Egr1_Fli1_Klf1_Spi1',
#  'Egr1_Fli1_Klf1_Zfpm1',
#  'Egr1_Fli1_Myc_Spi1',
#  'Egr1_Fli1_Myc_Zfpm1',
#  'Egr1_Fli1_Spi1_Zfpm1',
#  'Egr1_Gata1_Gata2_Ikzf1',
#  'Egr1_Gata1_Gata2_Junb',
#  'Egr1_Gata1_Gata2_Klf1',
#  'Egr1_Gata1_Gata2_Myc',
#  'Egr1_Gata1_Gata2_Spi1',
#  'Egr1_Gata1_Gata2_Zfpm1',
#  'Egr1_Gata1_Ikzf1_Spi1',
#  'Egr1_Gata1_Junb_Spi1',
#  'Egr1_Gata1_Klf1_Spi1',
#  'Egr1_Gata1_Myc_Spi1',
#  'Egr1_Gata1_Spi1_Zfpm1',
#  'Egr1_Gata2_Ikzf1_Junb',
#  'Egr1_Gata2_Ikzf1_Klf1',
#  'Egr1_Gata2_Ikzf1_Myc',
#  'Egr1_Gata2_Ikzf1_Spi1',
#  'Egr1_Gata2_Ikzf1_Zfpm1',
#  'Egr1_Gata2_Junb_Klf1',
#  'Egr1_Gata2_Junb_Myc',
#  'Egr1_Gata2_Junb_Spi1',
#  'Egr1_Gata2_Junb_Zfpm1',
#  'Egr1_Gata2_Klf1_Myc',
#  'Egr1_Gata2_Klf1_Spi1',
#  'Egr1_Gata2_Klf1_Zfpm1',
#  'Egr1_Gata2_Myc_Spi1',
#  'Egr1_Gata2_Myc_Zfpm1',
#  'Egr1_Gata2_Spi1_Zfpm1',
#  'Egr1_Ikzf1_Junb_Spi1',
#  'Egr1_Ikzf1_Klf1_Spi1',
#  'Egr1_Ikzf1_Myc_Spi1',
#  'Egr1_Ikzf1_Spi1_Zfpm1',
#  'Egr1_Junb_Klf1_Spi1',
#  'Egr1_Junb_Myc_Spi1',
#  'Egr1_Junb_Spi1_Zfpm1',
#  'Egr1_Klf1_Myc_Spi1',
#  'Egr1_Klf1_Spi1_Zfpm1',
#  'Egr1_Myc_Spi1_Zfpm1',
#  'Fli1_Gata1_Gata2_Ikzf1',
#  'Fli1_Gata1_Gata2_Junb',
#  'Fli1_Gata1_Gata2_Klf1',
#  'Fli1_Gata1_Gata2_Myc',
#  'Fli1_Gata1_Gata2_Spi1',
#  'Fli1_Gata1_Gata2_Zfpm1',
#  'Fli1_Gata1_Ikzf1_Junb',
#  'Fli1_Gata1_Ikzf1_Klf1',
#  'Fli1_Gata1_Ikzf1_Myc',
#  'Fli1_Gata1_Ikzf1_Spi1',
#  'Fli1_Gata1_Ikzf1_Zfpm1',
#  'Fli1_Gata1_Junb_Klf1',
#  'Fli1_Gata1_Junb_Myc',
#  'Fli1_Gata1_Junb_Spi1',
#  'Fli1_Gata1_Junb_Zfpm1',
#  'Fli1_Gata1_Klf1_Myc',
#  'Fli1_Gata1_Klf1_Spi1',
#  'Fli1_Gata1_Klf1_Zfpm1',
#  'Fli1_Gata1_Myc_Spi1',
#  'Fli1_Gata1_Myc_Zfpm1',
#  'Fli1_Gata1_Spi1_Zfpm1',
#  'Fli1_Gata2_Ikzf1_Junb',
#  'Fli1_Gata2_Ikzf1_Klf1',
#  'Fli1_Gata2_Ikzf1_Myc',
#  'Fli1_Gata2_Ikzf1_Spi1',
#  'Fli1_Gata2_Ikzf1_Zfpm1',
#  'Fli1_Gata2_Junb_Klf1',
#  'Fli1_Gata2_Junb_Myc',
#  'Fli1_Gata2_Junb_Spi1',
#  'Fli1_Gata2_Junb_Zfpm1',
#  'Fli1_Gata2_Klf1_Myc',
#  'Fli1_Gata2_Klf1_Spi1',
#  'Fli1_Gata2_Klf1_Zfpm1',
#  'Fli1_Gata2_Myc_Spi1',
#  'Fli1_Gata2_Myc_Zfpm1',
#  'Fli1_Gata2_Spi1_Zfpm1',
#  'Fli1_Ikzf1_Junb_Klf1',
#  'Fli1_Ikzf1_Junb_Myc',
#  'Fli1_Ikzf1_Junb_Spi1',
#  'Fli1_Ikzf1_Junb_Zfpm1',
#  'Fli1_Ikzf1_Klf1_Myc',
#  'Fli1_Ikzf1_Klf1_Spi1',
#  'Fli1_Ikzf1_Klf1_Zfpm1',
#  'Fli1_Ikzf1_Myc_Spi1',
#  'Fli1_Ikzf1_Myc_Zfpm1',
#  'Fli1_Ikzf1_Spi1_Zfpm1',
#  'Fli1_Junb_Klf1_Myc',
#  'Fli1_Junb_Klf1_Spi1',
#  'Fli1_Junb_Klf1_Zfpm1',
#  'Fli1_Junb_Myc_Spi1',
#  'Fli1_Junb_Myc_Zfpm1',
#  'Fli1_Junb_Spi1_Zfpm1',
#  'Fli1_Klf1_Myc_Spi1',
#  'Fli1_Klf1_Myc_Zfpm1',
#  'Fli1_Klf1_Spi1_Zfpm1',
#  'Fli1_Myc_Spi1_Zfpm1',
#  'Gata1_Gata2_Ikzf1_Junb',
#  'Gata1_Gata2_Ikzf1_Klf1',
#  'Gata1_Gata2_Ikzf1_Myc',
#  'Gata1_Gata2_Ikzf1_Spi1',
#  'Gata1_Gata2_Ikzf1_Zfpm1',
#  'Gata1_Gata2_Junb_Klf1',
#  'Gata1_Gata2_Junb_Myc',
#  'Gata1_Gata2_Junb_Spi1',
#  'Gata1_Gata2_Junb_Zfpm1',
#  'Gata1_Gata2_Klf1_Myc',
#  'Gata1_Gata2_Klf1_Spi1',
#  'Gata1_Gata2_Klf1_Zfpm1',
#  'Gata1_Gata2_Myc_Spi1',
#  'Gata1_Gata2_Myc_Zfpm1',
#  'Gata1_Gata2_Spi1_Zfpm1',
#  'Gata1_Ikzf1_Junb_Spi1',
#  'Gata1_Ikzf1_Klf1_Spi1',
#  'Gata1_Ikzf1_Myc_Spi1',
#  'Gata1_Ikzf1_Spi1_Zfpm1',
#  'Gata1_Junb_Klf1_Spi1',
#  'Gata1_Junb_Myc_Spi1',
#  'Gata1_Junb_Spi1_Zfpm1',
#  'Gata1_Klf1_Myc_Spi1',
#  'Gata1_Klf1_Spi1_Zfpm1',
#  'Gata1_Myc_Spi1_Zfpm1',
#  'Gata2_Ikzf1_Junb_Klf1',
#  'Gata2_Ikzf1_Junb_Myc',
#  'Gata2_Ikzf1_Junb_Spi1',
#  'Gata2_Ikzf1_Junb_Zfpm1',
#  'Gata2_Ikzf1_Klf1_Myc',
#  'Gata2_Ikzf1_Klf1_Spi1',
#  'Gata2_Ikzf1_Klf1_Zfpm1',
#  'Gata2_Ikzf1_Myc_Spi1',
#  'Gata2_Ikzf1_Myc_Zfpm1',
#  'Gata2_Ikzf1_Spi1_Zfpm1',
#  'Gata2_Junb_Klf1_Myc',
#  'Gata2_Junb_Klf1_Spi1',
#  'Gata2_Junb_Klf1_Zfpm1',
#  'Gata2_Junb_Myc_Spi1',
#  'Gata2_Junb_Myc_Zfpm1',
#  'Gata2_Junb_Spi1_Zfpm1',
#  'Gata2_Klf1_Myc_Spi1',
#  'Gata2_Klf1_Myc_Zfpm1',
#  'Gata2_Klf1_Spi1_Zfpm1',
#  'Gata2_Myc_Spi1_Zfpm1',
#  'Ikzf1_Junb_Klf1_Spi1',
#  'Ikzf1_Junb_Myc_Spi1',
#  'Ikzf1_Junb_Spi1_Zfpm1',
#  'Ikzf1_Klf1_Myc_Spi1',
#  'Ikzf1_Klf1_Spi1_Zfpm1',
#  'Ikzf1_Myc_Spi1_Zfpm1',
#  'Junb_Klf1_Myc_Spi1',
#  'Junb_Klf1_Spi1_Zfpm1',
#  'Junb_Myc_Spi1_Zfpm1',
#  'Klf1_Myc_Spi1_Zfpm1',
#  'MP']

# %%
# Identifying models from 'diff' with identical attractors reachability as the most permissive dynamics
mp_same = [d for d in asyn_diff if answer["MP"] == answer[d]]
mp_same
# Out:
# ['Egr1_Fli1_Gata1_Gata2', 'MP']
